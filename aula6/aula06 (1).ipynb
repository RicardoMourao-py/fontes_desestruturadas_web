# %% [markdown]
# # Análise de texto de fontes desestruturadas e Web
#
# ## Aula 06
#
# Nesta aula iremos continuar a extrair informações de páginas Web! Primeiro, iremos realizar a extração de informações de produtos de uma página sintética. Em seguida, realizaremos buscas nos sites do InstoÉDinheiro e Magazine Luiza e extrair informações dos resultados.
#
# A biblioteca utilizada será a **BeautifulSoup**, além da **requests**.
#
# Para conhecer mais sobre ela, acesse https://beautiful-soup-4.readthedocs.io/en/latest/

# %% [markdown]
# ## Instalando a biblioteca *BeautifulSoup*
#
# Primeiro, vamos instalar a principal biblioteca de nossa aula!

# %%
#!pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.9/dist-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from BeautifulSoup4) (2.4)

# %% [markdown]
# Caso a biblioteca já esteja instalada, porém com uma versão antiga, podemos atualizá-la com:

# %%
#!pip install BeautifulSoup4 -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.9/dist-packages (4.9.3)
# Collecting BeautifulSoup4
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from BeautifulSoup4) (2.4)
# Installing collected packages: BeautifulSoup4
#   Attempting uninstall: BeautifulSoup4
#     Found existing installation: beautifulsoup4 4.9.3
#     Uninstalling beautifulsoup4-4.9.3:
#       Successfully uninstalled beautifulsoup4-4.9.3
# Successfully installed BeautifulSoup4-4.11.2

# %% [markdown]
# ## Importando as bibliotecas necessárias
#
# Agora, vamos importar as bibliotecas necessárias:

# %%
# para trabalhar com diretórios / sistema operacional
import os

# para nos comunicarmos com a Web
import requests

# para extrair informações de páginas HTML
import bs4
from bs4 import BeautifulSoup

# utilizada para nos indicar o caminho do executável do Python
import sys

# Para criar um Data Frame
import pandas as pd

# Controlar espera entre requisições
import time

# Gerar valores aleatórios
import random

# Produto cartesiano
from sklearn.utils.extmath import cartesian

# Renderizar HTML
import IPython

# %% [markdown]
# Caso obtenha algum erro, utilize o **!pip install** para instalar a biblioteca ausente!
#
# Vamos conferir com qual versão da biblioteca **xxxx** estamos trabalhando?

# %%
print(bs4.__version__)
# Out:
# 4.11.2

# %% [markdown]
# Você também pode conferir de onde está executando o Python e qual a versão

# %%
print('Executável:')
print(sys.executable)

print('\nVersão do Python:')
print(sys.version)
# Out:
# Executável:
# /usr/bin/python3
#
# Versão do Python:
# 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]

# %% [markdown]
# Vamos conferir em qual diretório iremos trabalhar (é o diretório do notebook)

# %%
print('O seu notebook está na pasta:')
print(os.getcwd())
# Out:
# O seu notebook está na pasta:
# /content

# %% [markdown]
# ## Exemplo de aplicação
#
# Suponha que tenhamos uma página Web com diversos produtos listados.
#
# Acesse https://atd-insper.s3.us-east-2.amazonaws.com/aula05/produtos.html
#
# Vamos utilizar o BeautifulSoup para extrair as informações da página, construindo um **pandas DataFrame** contendo o **`produto`**, **`descrição`** e **`preço`**.
#
# Primeiro, vamos extrair a página com o *requests*:

# %%
url = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula05/produtos.html'

pag_prod = requests.get(url)

pag_prod.encoding = 'utf-8'

print(pag_prod.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
#         <meta charset="UTF-8">
#         <title>Exemplo Produtos</title>
#     </head>
# <body>
#
# <div class="menu" id="my_menu" align="right">
# 	<a href="#">HOME</a> | <a href="macielcv@insper.edu.br">CONTATO</a> | <a href="https://www.google.com">GOOGLE</a>
# </div>
#
#
# <div class="produto" id="produto_1" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
# 	<p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
#     <span class="preco_produto" id="preco_produto_1">R$&nbsp;4.299,00</span>
# </div>
#
#
# <div class="produto" id="produto_2" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i7-8565U 8GB 2TB Placa de Vídeo 2GB Tela Full HD 15.6” Windows 10 Inspiron I15-3583-A40B</h4>
# 	<p>Intel® Core™ i7-8565U Quad Core 1.8 GHz com Turbo Max até 4.6 GHz. Windows 10 Home Single Language 64 bits.</p>
#     <span class="preco_produto" id="preco_produto_2">R$&nbsp;5.499,00</span>
# </div>
#
#
# <div class="produto" id="produto_3" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Gamer Dell G3 3500-U10P</h4>
# 	<p>Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Real: GRÁFICOS Poderosos, Desempenho Extremamente RÁPIDO E Sistema TÉRMICO Especial. Com o novo notebook Dell G3, você terá uma incrível experiência em um notebook com um design fino, leve e com uma performance incrível.</p>
#     <span class="preco_produto" id="preco_produto_3">R$&nbsp;6.049,00</span>
# </div>
#
#
# <div class="produto" id="produto_4" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15.6” Windows 10 Ideapad S145</h4>
# 	<p>Design sofisticado leve e compacto, possui tela antirreflexo de 15.6" para mais conforto visual e definição de imagem. Um notebook perfeito para produtividade e entretenimento com WiFi AC ultrarrápido e teclado numérico.</p>
#     <span class="preco_produto" id="preco_produto_4">R$&nbsp;3.199,00</span>
# </div>
#
#
# <div class="produto" id="produto_5" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb SSD W10 Pro</h4>
# 	<p>O teclado numérico BS145 integrado garante uma digitação mais rápida e ergonômica, especialmente para facilitar o trabalho com cálculos e planilhas. Tela anti-reflexo de 15,6 polegadas que pode ser aberta em 180 °, dando a você mais flexibilidade no ajuste do ângulo de visão e tornando a integridade da dobradiça mais segura.</p>
#     <span class="preco_produto" id="preco_produto_5">R$&nbsp;6.781,00</span>
# </div>
#
# </body>
# </html>

# %% [markdown]
# Podemos abrir diretamente a URL em um navegador para verificar seu conteúdo, ou então renderizar dentro do notebook com:

# %%
IPython.display.HTML(pag_prod.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
#         <meta charset="UTF-8">
#         <title>Exemplo Produtos</title>
#     </head>
# <body>
#
# <div class="menu" id="my_menu" align="right">
# 	<a href="#">HOME</a> | <a href="macielcv@insper.edu.br">CONTATO</a> | <a href="https://www.google.com">GOOGLE</a>
# </div>
#
#
# <div class="produto" id="produto_1" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
# 	<p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
#     <span class="preco_produto" id="preco_produto_1">R$&nbsp;4.299,00</span>
# </div>
#
#
# <div class="produto" id="produto_2" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Dell Core i7-8565U 8GB 2TB Placa de Vídeo 2GB Tela Full HD 15.6” Windows 10 Inspiron I15-3583-A40B</h4>
# 	<p>Intel® Core™ i7-8565U Quad Core 1.8 GHz com Turbo Max até 4.6 GHz. Windows 10 Home Single Language 64 bits.</p>
#     <span class="preco_produto" id="preco_produto_2">R$&nbsp;5.499,00</span>
# </div>
#
#
# <div class="produto" id="produto_3" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Gamer Dell G3 3500-U10P</h4>
# 	<p>Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Real: GRÁFICOS Poderosos, Desempenho Extremamente RÁPIDO E Sistema TÉRMICO Especial. Com o novo notebook Dell G3, você terá uma incrível experiência em um notebook com um design fino, leve e com uma performance incrível.</p>
#     <span class="preco_produto" id="preco_produto_3">R$&nbsp;6.049,00</span>
# </div>
#
#
# <div class="produto" id="produto_4" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15.6” Windows 10 Ideapad S145</h4>
# 	<p>Design sofisticado leve e compacto, possui tela antirreflexo de 15.6" para mais conforto visual e definição de imagem. Um notebook perfeito para produtividade e entretenimento com WiFi AC ultrarrápido e teclado numérico.</p>
#     <span class="preco_produto" id="preco_produto_4">R$&nbsp;3.199,00</span>
# </div>
#
#
# <div class="produto" id="produto_5" align="left" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# 	<h4>Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb SSD W10 Pro</h4>
# 	<p>O teclado numérico BS145 integrado garante uma digitação mais rápida e ergonômica, especialmente para facilitar o trabalho com cálculos e planilhas. Tela anti-reflexo de 15,6 polegadas que pode ser aberta em 180 °, dando a você mais flexibilidade no ajuste do ângulo de visão e tornando a integridade da dobradiça mais segura.</p>
#     <span class="preco_produto" id="preco_produto_5">R$&nbsp;6.781,00</span>
# </div>
#
# </body>
# </html>

# %% [markdown]
# Vamos utilizar o BeautifulSoup

# %%
soup = BeautifulSoup(pag_prod.text, 'html.parser')

# %% [markdown]
# E extrair a lista de produtos

# %%
lista_produto = soup.find_all('div', class_='produto')
lista_produto
# Out:
# [<div align="left" class="produto" id="produto_1" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
#  <p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
#  <span class="preco_produto" id="preco_produto_1">R$ 4.299,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_2" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Dell Core i7-8565U 8GB 2TB Placa de Vídeo 2GB Tela Full HD 15.6” Windows 10 Inspiron I15-3583-A40B</h4>
#  <p>Intel® Core™ i7-8565U Quad Core 1.8 GHz com Turbo Max até 4.6 GHz. Windows 10 Home Single Language 64 bits.</p>
#  <span class="preco_produto" id="preco_produto_2">R$ 5.499,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_3" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Gamer Dell G3 3500-U10P</h4>
#  <p>Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Real: GRÁFICOS Poderosos, Desempenho Extremamente RÁPIDO E Sistema TÉRMICO Especial. Com o novo notebook Dell G3, você terá uma incrível experiência em um notebook com um design fino, leve e com uma performance incrível.</p>
#  <span class="preco_produto" id="preco_produto_3">R$ 6.049,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_4" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15.6” Windows 10 Ideapad S145</h4>
#  <p>Design sofisticado leve e compacto, possui tela antirreflexo de 15.6" para mais conforto visual e definição de imagem. Um notebook perfeito para produtividade e entretenimento com WiFi AC ultrarrápido e teclado numérico.</p>
#  <span class="preco_produto" id="preco_produto_4">R$ 3.199,00</span>
#  </div>,
#  <div align="left" class="produto" id="produto_5" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
#  <h4>Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb SSD W10 Pro</h4>
#  <p>O teclado numérico BS145 integrado garante uma digitação mais rápida e ergonômica, especialmente para facilitar o trabalho com cálculos e planilhas. Tela anti-reflexo de 15,6 polegadas que pode ser aberta em 180 °, dando a você mais flexibilidade no ajuste do ângulo de visão e tornando a integridade da dobradiça mais segura.</p>
#  <span class="preco_produto" id="preco_produto_5">R$ 6.781,00</span>
#  </div>]

# %% [markdown]
# Podemos obter um produto qualquer da lista, bastando informar o índice da lista

# %%
produto = lista_produto[0]
produto
# Out:
# <div align="left" class="produto" id="produto_1" style="width:600px;height:160px; background-color:rgb(115, 185, 174);">
# <h4>Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP</h4>
# <p>Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.</p>
# <span class="preco_produto" id="preco_produto_1">R$ 4.299,00</span>
# </div>

# %% [markdown]
# Então, podemos obter as informações de **PRODUTO**, **DESCRIÇÃO** e **PREÇO**!

# %%
produto_titulo = produto.find('h4').text
descricao = produto.find('p').text
preco = produto.find('span').text

print('Produto....: ', produto_titulo)
print('\nDescrição..: ', descricao)
print('\nPreço......: ', preco)
# Out:
# Produto....:  Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6” Windows 10 Inspiron I15-3583-A3XP
#
# Descrição..:  Com o notebook Dell Inspiron I15-3583-A3XP você conta com todos os recursos essenciais para o seu dia a dia. Sua estrutura leve e fina garante a portabilidade ideal para levar aonde quiser.
#
# Preço......:  R$ 4.299,00

# %% [markdown]
# ### Obter todos os produtos e construir o DataFrame!
#
# Para obter as informações de todos os produtos de forma fácil, podemos iterar (laço, estrutura de repetição **for**) sobre as *div*'s de todos os produtos e extrair as informações para cada uma delas.
#
# Podemos guardar cada produto, descrição e preço em uma lista, o que facilitará a construção do DataFrame.

# %%
lista_prod_titulo = []
lista_descricao = []
lista_preco = []

for produto in soup.find_all('div', class_='produto'):
    produto_titulo = produto.find('h4').text
    descricao = produto.find('p').text
    preco = produto.find('span').text
    
    preco = preco.replace('R$\xa0', '')
    preco = float(preco.replace(".", "").replace(",", "."))

    
    lista_prod_titulo.append(produto_titulo)
    lista_descricao.append(descricao)
    lista_preco.append(preco)

# %% [markdown]
# Agora, com as listas de produto, descrição e preço, podemos construir o DataFrame!

# %%
df = pd.DataFrame({'Produto': lista_prod_titulo,
                   'Descrição': lista_descricao,
                   'Preço': lista_preco
                  })
df
# Out:
#                                              Produto  \
# 0  Notebook Dell Core i5-8265U 8GB 1TB Tela 15.6”...
# 1  Notebook Dell Core i7-8565U 8GB 2TB Placa de V...
# 2                   Notebook Gamer Dell G3 3500-U10P
# 3  Notebook Lenovo Core i3-8130U 4GB 1TB Tela 15....
# 4  Notebook Lenovo BS145 Intel Core I5 4Gb 256Gb ...
#
#                                            Descrição   Preço
# 0  Com o notebook Dell Inspiron I15-3583-A3XP voc...  4299.0
# 1  Intel® Core™ i7-8565U Quad Core 1.8 GHz com Tu...  5499.0
# 2  Sua EXPERIÊNCIA Gamer Ainda Mais Intensa E Rea...  6049.0
# 3  Design sofisticado leve e compacto, possui tel...  3199.0
# 4  O teclado numérico BS145 integrado garante uma...  6781.0

# %% [markdown]
# Você conseguiria pensar em alguma aplicação prática feita a partir deste exemplo?

# %% [markdown]
# <div class="alert alert-success">
#
# Sua resposta aqui! Dê dois cliques e edite.
#
# </div>

# %% [markdown]
# ## IstoÉDinheiro
#
# Vamos utilizar `requests` para baixar (`get`) notícias do site da **IstoÉDinheiro** e `BeautifulSoup` para extrair informações e construir um Pandas `DataFrame` de títulos e descrições.
#
# ### Definindo qual página buscar
#
# Faremos algumas configurações (cabeçalho, seção e URL):

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

secao = 'economia'

url = f'https://www.istoedinheiro.com.br/categoria/{secao}/'

# %% [markdown]
# ### Utilizando *requests* para baixar a página de notícias
#
# E utilizar `requests` para baixar a página de notícias:

# %%
resposta = requests.get(url=url, headers=headers)

resposta.encoding = 'utf-8'

resposta.text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="pt-BR">\n<head>\n\t<meta charset="UTF-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t<meta name="theme-color" content="#D00018">\n\t<link rel="profile" href="http://gmpg.org/xfn/11" />\n\t<link href="https://www.istoedinheiro.com.br/wp-content/themes/tema_dinheiro/assets/images/favicon_dinheiro_32X32-v21.ico" rel="shortcut icon" />\n  <meta name=\'dailymotion-domain-verification\' content=\'dm8ibc0sv94vdc6bk\' />\n\t<meta name=\'robots\' content=\'max-image-preview:large\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v14.2 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<meta name="robots" content="index, follow" />\n\t<meta name="googlebot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<meta name="bingbot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<link rel="canonical" href="https://www.istoedinheiro.com.br/categoria/economia/" />\n\t<link rel="next" href="https://www.istoedinheiro.com.br/categoria/economia/page/2/" />\n\t<meta property="og:locale" content="pt_BR" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Economia - ISTOÉ DINHEIRO" />\n\t<meta property="og:url" content="https://www.istoedinheiro.com.br/categoria/economia/" />\n\t<meta property="og:site_name" content="ISTOÉ DINHEIRO" />\n\t<meta property="og:image" content="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/2021/04/dinheiro-facebook.png" />\n\t<meta property="og:image:width" content="1200" />\n\t<meta property="og:image:height" content="630" />\n\t<meta property="fb:app_id" content="897801760242827" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:site" content="@RevistaDinheiro" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.istoedinheiro.com.br/#website","url":"https://www.istoedinheiro.com.br/","name":"ISTO\\u00c9 DINHEIRO","description":"Portal de not\\u00edcias e an\\u00e1lises de economia, neg\\u00f3cios, finan\\u00e7as, tecnologia e investimentos","potentialAction":[{"@type":"SearchAction","target":"https://www.istoedinheiro.com.br/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"pt-BR"},{"@type":"CollectionPage","@id":"https://www.istoedinheiro.com.br/categoria/economia/#webpage","url":"https://www.istoedinheiro.com.br/categoria/economia/","name":"Economia - ISTO\\u00c9 DINHEIRO","isPartOf":{"@id":"https://www.istoedinheiro.com.br/#website"},"inLanguage":"pt-BR"}]}</script>\n\t<!-- / Yoast SEO plugin. -->\n\n\n<link rel=\'dns-prefetch\' href=\'//www.istoedinheiro.com.br\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Feed para ISTOÉ DINHEIRO &raquo;" href="https://www.istoedinheiro.com.br/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Feed de comentários para ISTOÉ DINHEIRO &raquo;" href="https://www.istoedinheiro.com.br/comments/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Feed de categoria para ISTOÉ DINHEIRO &raquo; Economia" href="https://www.istoedinheiro.com.br/categoria/economia/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/www.istoedinheiro.com.br\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.7.2"}};\n\t\t\t!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.cle ...

# %% [markdown]
# ### Extraindo informações relevantes com *BeautifulSoup*
# Perceba que o HTML inclui uma grande quantidade de tags, o que dificulta identificar informações relevantes de forma direta. Com o auxílio da biblioteca **BeautifulSoup** podemos extrair facilmente as informações que desejamos.

# %%
soup = BeautifulSoup(resposta.text, 'html.parser')

# %% [markdown]
# Então, vamos obter uma lista com todos os trechos HTML que contém uma **notícia**.
#
# Para identificar as tags corretas, é preciso ir até a página Web que desejamos extrair informações, dar botão direito e ir em **inspecionar elemento**, navegando pelo HTML até identificar as tags necessárias
#
# Ex: https://www.istoedinheiro.com.br/categoria/economia/

# %%
lista_tag_noticia = soup.find_all('article', class_ = 'thumb')
lista_tag_noticia[0]
# Out:
# <article class="thumb">
# <div class="bloco-noticias-share-post share-noticias-no-image">
# </div>
# <div class="row">
# <div class="wrapper-image">
# <!--<a href="" title="" class="link-category link-cat-mob">Mundo</a>-->
# <a class="c-container-img" href="https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação">
# <img alt="" src="https://www.istoedinheiro.com.br/wp-content/uploads/sites/17/Reuters_Direct_Media/BrazilOnlineReportTopNews/tagreuters.com2023binary_LYNXMPEJ2F0Q1-BASEIMAGE-418x235.jpg" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação"/>
# </a>
# </div>
# <div class="wrapper-title">
# <h3>
# <a href="https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação">Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação</a>
# </h3>
# <a class="description" href="https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/" title="Governo francês usa procedimento especial para aprovar reforma previdenciária sem votação">
# <p>Por Elizabeth Pineau PARIS (Reuters) – A primeira-ministra francesa, Elisabeth Borne, acionou um procedimento especial para aprovar um impopular projeto de reforma da previdência na Assembleia Nacional nesta quinta-feira sem uma votação, em meio a gritos de parlamentares da esquerda contra a reforma. A medida, usando o chamado artigo 49.3 da Constituição, garantirá que o […]</p>
# <time class="c-data" datetime="2023-03-16 18:14">16/03/2023 18:14</time>
# </a>
# <div class="share-post-mb"></div>
# </div>
# </div>
# </article>

# %% [markdown]
# Agora, podemos passar por cada uma das chamadas de notícias, extraindo informações de interesse, como o título, descrição e data.

# %%
lista_titulo = []
lista_desc = []
lista_data = []

for i in range(0, len(lista_tag_noticia)):
    
    tag_noticia = lista_tag_noticia[i]


    titulo = tag_noticia.find('h3').text
    titulo = titulo.replace('\n', '') #limpa os ENTERS a esquerda e direita
    lista_titulo.append(titulo)

    descricao = tag_noticia.find('p').text
    lista_desc.append(descricao)
    
    data_hora = tag_noticia.find('time').text
    lista_data.append(data_hora)

# %% [markdown]
# ## Criando um DataFrame
#
# As informações que consideramos foram extraídas na repetição **for** e armazenadas em listas. Podemos utilizar estas listas para construir um Pandas DataFrame:

# %%
df = pd.DataFrame({'Secao': secao,
                   'Titulo': lista_titulo,
                   'Descrição': lista_desc,
                   'Data': lista_data
                  })
df
# Out:
#        Secao                                             Titulo  \
# 0   economia  Governo francês usa procedimento especial para...
# 1   economia  Lucro da Caramuru sobe 52% no 4º tri, mas cai ...
# 2   economia  Polônia enviará 4 jatos MiG-29 à Ucrânia nos p...
# 3   economia  Número de mortos por ciclone Freddy passa de 4...
# 4   economia  EcoRodovias: lucro líquido recorrente no 4º tr...
# 5   economia  França: cias aéreas me procuraram; querem desm...
# 6   economia  Reino Unido e sindicatos de profissionais de s...
# 7   economia  Argentina: BC eleva taxa básica de juros em 30...
# 8   economia  Bancos depositarão US$ 30 bilhões no First Rep...
# 9   economia  Seara aposta em tecnologia 4.0 para segmento d...
# 10  economia  Bancos suspendem consignado do INSS após gover...
# 11  economia  IGC vê avanço na produção global de grãos em 2...
# 12  economia  Dano moral previdenciário: quando se aplica e ...
# 13  economia  ‘Não vejo espaço para crise chegar a bancos do...
# 14  economia    Europa: medo de contágio testa força dos bancos
# 15  economia  Exportações de soja e milho dos EUA se animam ...
# 16  economia  Argentina reduz novamente previsão de produção...
# 17  economia  Chuvas na próxima semana na Argentina marcam i...
# 18  economia  Explosão em prédio da FSB no sul da Rússia dei...
# 19  economia  EUA devem pagar todas as suas dívidas, diz sec...
#
#                                             Descrição              Data
# 0   Por Elizabeth Pineau PARIS (Reuters) – A prime...  16/03/2023 18:14
# 1   Por Nayara Figueiredo SÃO PAULO (Reuters) – A ...  16/03/2023 18:13
# 2   VARSÓVIA (Reuters) – A Polônia enviará à Ucrân...  16/03/2023 18:10
# 3   Por Tom Gibb e Frank Phiri BLANTYRE (Reuters) ...  16/03/2023 18:05
# 4   A EcoRodovias reportou lucro líquido recorrent...  16/03/2023 18:01
# 5   O “Voa, Brasil”, como está sendo chamado um pr...  16/03/2023 17:59
# 6   Por Muvija M e Sachin Ravikumar LONDRES (Reute...  16/03/2023 17:54
# 7   O Banco Central da República Argentina (BCRA) ...  16/03/2023 17:35
# 8   Um grupo de 11 bancos americanos e que inclui ...  16/03/2023 17:33
# 9   Por Nayara Figueiredo SÃO PAULO (Reuters) – A ...  16/03/2023 17:30
# 10  Os bancos começaram nesta quinta-feira, 16, a ...  16/03/2023 17:17
# 11  LONDRES (Reuters) – A produção global de grãos...  16/03/2023 17:15
# 12  O Instituto Nacional do Seguro Social (INSS) t...  16/03/2023 17:02
# 13  Ex-diretor do Banco Central, José Júlio Senna ...  16/03/2023 17:02
# 14  A queda acentuada recente nas ações do Credit ...  16/03/2023 16:51
# 15  Por Karen Braun NAPERVILLE, ILLINOIS (Reuters)...  16/03/2023 16:42
# 16  BUENOS AIRES (Reuters) – A produção de soja da...  16/03/2023 16:21
# 17  Por Maximilian Heath BUENOS AIRES (Reuters) – ...  16/03/2023 16:21
# 18  ROSTOV-ON-DON, Rússia (Reuters) – Pelo menos u...  16/03/2023 16:13
# 19  A secretária do Tesouro dos Estados Unidos, Ja...  16/03/2023 15:37

# %% [markdown]
# ### Salvando o DataFrame em CSV
#
# É interessante armazenar o Dataframe em **CSV** (ou **xlsx**) para que ele possa ser análisado em algum momento posterior. Você poderia, por exemplo, extrair as notícias todos os dias de uma semana e analisar somente após ter todos estes dados.

# %%
df.to_csv(f'noticias_{secao}_160323.csv', index=False)

# %% [markdown]
# # Exercícios
#
#
# **Exercício 1)** Altere o código de extração das informações das notícias para trazer também o **link da notícia**. Rode todo o código novamente.

# %%
lista_tag_noticia[0].find('a')['href']
# Out:
# 'https://www.istoedinheiro.com.br/governo-frances-usa-procedimento/'

# %% [markdown]
# **Exercício 2)** Crie um CSV (pesquise e salve) com as notícias das seções de **economia**, **política** e **finanças**.
#
# Faça a pesquisa e gere o `DataFrame` e **CSV** com cada uma das seções. Observe como a IstoÉ as nomeia em seu site.
#
# Em seguida, abra os três arquivos e os concatene, gerando apenas um DataFrame contendo todas as notícias das três seções (dica: pd.concat).

# %%
lista = ['economia', 'politica', 'financas']

lista_titulo = []
lista_desc = []
lista_data = []
lista_secao = []

for j in lista:
  url = f'https://www.istoedinheiro.com.br/categoria/{j}/'
  resposta = requests.get(url=url, headers=headers)
  resposta.encoding = 'utf-8'
  soup = BeautifulSoup(resposta.text, 'html.parser')
  lista_tag_noticia = soup.find_all('article', class_ = 'thumb')
  for i in range(0, len(lista_tag_noticia)):
      
      tag_noticia = lista_tag_noticia[i]

      titulo = tag_noticia.find('h3').text
      titulo = titulo.replace('\n', '') #limpa os ENTERS a esquerda e direita
      lista_titulo.append(titulo)

      descricao = tag_noticia.find('p').text
      lista_desc.append(descricao)
      
      data_hora = tag_noticia.find('time').text
      lista_data.append(data_hora)

      lista_secao.append(j)

# %%
df = pd.DataFrame({'Secao': lista_secao,
                   'Titulo': lista_titulo,
                   'Descrição': lista_desc,
                   'Data': lista_data
                  })
df.tail()
# Out:
#        Secao                                             Titulo  \
# 55  financas  Taxas de juros rondam estabilidade antes de BC...
# 56  financas  Bolsas da Europa se recuperam parcialmente apó...
# 57  financas  Bolsas da Ásia caem, após Credit Suisse renova...
# 58  financas  Dólar fecha no maior nível desde 5 de janeiro ...
# 59  financas  Juros: Taxas caem alinhadas à queda dos retorn...
#
#                                             Descrição              Data
# 55  Após caírem na quarta-feira, 15, os juros rond...  16/03/2023 09:42
# 56  As bolsas europeias operavam em alta na manhã ...  16/03/2023 07:59
# 57  As bolsas asiáticas fecharam em baixa nesta qu...  16/03/2023 07:15
# 58  O dólar encerrou a sessão desta quarta-feira, ...  15/03/2023 18:18
# 59  O ambiente externo continuou servindo de refer...  15/03/2023 18:16

# %% [markdown]
# **Exercício 3)** Crie uma solução em Python que faça o download de várias páginas (1, 2, 3, ...) de notícias do IstoÉDinheiro. Defina no inicio do código variáveis de **página inicial** e **página** final.
#
# Como resultado, produza um `DataFrame` contendo todas as notícias. Adicione uma coluna com o número da página onde a notícia aparece.

# %%
lista_titulo = []
lista_desc = []
lista_data = []
lista_site = []

for j in range(10):
  url = f'https://www.istoedinheiro.com.br/categoria/{secao}/page/{i}'
  resposta = requests.get(url=url, headers=headers)
  resposta.encoding = 'utf-8'
  soup = BeautifulSoup(resposta.text, 'html.parser')
  lista_tag_noticia = soup.find_all('article', class_ = 'thumb')
  for i in range(0, len(lista_tag_noticia)):
      
      tag_noticia = lista_tag_noticia[i]

      titulo = tag_noticia.find('h3').text
      titulo = titulo.replace('\n', '') #limpa os ENTERS a esquerda e direita
      lista_titulo.append(titulo)

      descricao = tag_noticia.find('p').text
      lista_desc.append(descricao)
      
      data_hora = tag_noticia.find('time').text
      lista_data.append(data_hora)

      lista_site.append(j)

# %%
df = pd.DataFrame({'Page': lista_site,
                   'Titulo': lista_titulo,
                   'Descrição': lista_desc,
                   'Data': lista_data
                  })
df.tail()
# Out:
#      Page                                             Titulo  \
# 195     9  Explosão em evento de jornalistas no Afeganist...
# 196     9  Inundações e ventos fortes atingem Moçambique ...
# 197     9        STF suspende julgamento da Lei das Estatais
# 198     9  Governo libera linha adicional para agricultor...
# 199     9  BC pergunta sobre ‘atenção’ no crédito e reone...
#
#                                              Descrição              Data
# 195  CABUL (Reuters) – Uma explosão que atingiu um ...  11/03/2023 15:00
# 196  MAPUTO (Reuters) – O ciclone Freddy estava se ...  11/03/2023 14:50
# 197  O Supremo Tribunal Federal (STF) interrompeu n...  11/03/2023 14:43
# 198  O presidente Luiz Inácio Lula da Silva e o min...  11/03/2023 14:30
# 199  Em meio ao debate no mercado sobre uma ameaça ...  11/03/2023 13:45

# %% [markdown]
# ## Magazine Luiza
#
# Iremos utilizar o BeautifulSoup para extrair informações sobre produtos de um site do varejo brasileiro!
#
# Vamos descobrir como funciona o site da Magazine Luiza? Iremos acessar https://www.magazineluiza.com.br. Após acessar o site, clique com o botão direito do mouse e selecione **Inspecionar Elemento**.
#
# Faça uma busca no site utilizando algum termo como **'smartphone 128gb'**.
#
# Tente inspecionar vários elementos até encontrar padrões:
# - Onde está a **lista de produtos** retornada pela busca?
# - Como obter do produto:
#     - A **descrição**
#     - O **preço**
#     - A URL da **imagem**
#     - Etc.

# %% [markdown]
# ### Arquivos `robots.txt`
#
# Os sites costumam deixar no arquivo robots.txt as informações de boas práticas de web **crawling** e **scraping**.
#
# Vamos conferir o robots.txt da Magazine Luiza?
#
# Acesse https://www.magazineluiza.com.br/robots.txt ou faça um requests.
#
# Acesse https://developers.google.com/search/docs/advanced/robots/create-robots-txt?hl=pt-br para saber mais.

# %% [markdown]
# ### User-agent
#
# Alguns sites bloqueiam requisições identificadas como não realizadas por usuários em navegadores. Para prevenir bloqueios e extrair informações destes sites, uma prática é criar um cabeçalho com **User-Agent**.

# %%
# headers = ({'User-Agent':
#             'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'})

headers = {
     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.35 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.35'
}

# %% [markdown]
# Você também pode alterar o **User-Agent** a cada nova requisição. O cabeçalho também pode ter informações de login por exemplo, mas isso foge do escopo da disciplina!

# %% [markdown]
# ### Buscando um produto
#
# Vamos acessar o site https://www.magazineluiza.com.br e realizar a busca manual por algum produto.
#
# Digite algo no campo de busca e realize a busca. Observe que a URL irá ser alterada e conter os seus termos de busca.
#
# Edite a URL diretamente para realizar a busca por outros produtos (direto na barra de endereços do navegador ao invés de utilizar o campo de buscas do site).

# %% [markdown]
# Alguns exemplos de busca:
#
# - https://www.magazineluiza.com.br/busca/smartphone+128gb/
# - https://www.magazineluiza.com.br/busca/smartphone+256gb/

# %%
url = 'https://www.magazineluiza.com.br/busca/smartphone+128gb/'

resposta = requests.get(url=url, headers=headers)

resposta.encoding = 'utf-8'

resposta.text
# Out:
# '<!DOCTYPE html><html lang="pt-br"><head><link rel="shortcut icon" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-16x16.png"/><link rel="apple-touch-icon-precomposed" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-96x96.png" sizes="96x96"/><link rel="apple-touch-icon-precomposed" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-72x72.png" sizes="72x72"/><link rel="apple-touch-icon-precomposed" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-57x57.png"/><link rel="shortcut icon" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-16x16.png" type="image/ico"/><link rel="preconnect" href="https://6590300.fls.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://a-static.mlcdn.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://adservice.google.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://adservice.google.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://analytics.tiktok.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://bat.bing.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://c.mlcdn.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://cas.avalon.perfdrive.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://cdn.navdmp.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://cdn.perfdrive.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://cm.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://connect.facebook.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://ct.pinterest.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://device.4seeresults.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://dpm.demdex.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://googleads.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://gum.criteo.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://i.btg360.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://iosite.reclameaqui.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://mms-assets.magazineluiza.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://pagead2.googlesyndication.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://pixel.tapad.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://pubads.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://rgr.bob-recs" crossorigin="true" defer=""/><link rel="preconnect" href="https://s.mlcdn.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://s.pinimg.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://s3.amazonaws.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://script.hotjar.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://securepubads.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://sp.analytics.yahoo.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://static.hotjar.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://stats.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://vars.hotjar.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://vc.hotjar.io" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.google-analytics.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.google.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.google.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="tru ...

# %%
resposta.request.headers
# Out:
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.35 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.35', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# Conferindo o código de resposta

# %%
print('Código de status da resposta: {}'.format(resposta.status_code))
# Out:
# Código de status da resposta: 200

# %% [markdown]
# e o texto de resposta

# %%
print('Texto de resposta:')
print(resposta.text)
# Out:
# Texto de resposta:
# <!DOCTYPE html><html lang="pt-br"><head><link rel="shortcut icon" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-16x16.png"/><link rel="apple-touch-icon-precomposed" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-96x96.png" sizes="96x96"/><link rel="apple-touch-icon-precomposed" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-72x72.png" sizes="72x72"/><link rel="apple-touch-icon-precomposed" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-57x57.png"/><link rel="shortcut icon" href="https://wx.mlcdn.com.br/site/shared/favicon/favicon-16x16.png" type="image/ico"/><link rel="preconnect" href="https://6590300.fls.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://a-static.mlcdn.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://adservice.google.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://adservice.google.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://analytics.tiktok.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://bat.bing.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://c.mlcdn.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://cas.avalon.perfdrive.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://cdn.navdmp.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://cdn.perfdrive.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://cm.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://connect.facebook.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://ct.pinterest.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://device.4seeresults.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://dpm.demdex.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://googleads.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://gum.criteo.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://i.btg360.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://iosite.reclameaqui.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://mms-assets.magazineluiza.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://pagead2.googlesyndication.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://pixel.tapad.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://pubads.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://rgr.bob-recs" crossorigin="true" defer=""/><link rel="preconnect" href="https://s.mlcdn.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://s.pinimg.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://s3.amazonaws.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://script.hotjar.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://securepubads.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://sp.analytics.yahoo.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://static.hotjar.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://stats.g.doubleclick.net" crossorigin="true" defer=""/><link rel="preconnect" href="https://vars.hotjar.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://vc.hotjar.io" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.google-analytics.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.google.com.br" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.google.com" crossorigin="true" defer=""/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true ...
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({originalLocation: document.location.protocol+'//'+
#     document.location.hostname+document.location.pathname+document.location.search});
#     w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-BR2N')
#   </script><script async="" src="https://px.bob-recs.com/stewie-3.0.0.min.js"></script><script defer="" src="https://i.btg360.com.br/btg360-2.0.1.min.js"></script><script defer="" src="https://static.criteo.net/js/ld/ld.js"></script><script>
#   !function (w, d, t) {
#     w.TiktokAnalyticsObject=t;var ttq=w[t]=w[t]||[];ttq.methods=["page","track","identify","instances","debug","on","off","once","ready","alias","group","enableCookie","disableCookie"],ttq.setAndDefer=function(t,e){t[e]=function(){t.push([e].concat(Array.prototype.slice.call(arguments,0)))}};for(var i=0;i<ttq.methods.length;i++)ttq.setAndDefer(ttq,ttq.methods[i]);ttq.instance=function(t){for(var e=ttq._i[t]||[],n=0;n<ttq.methods.length;n++)ttq.setAndDefer(e,ttq.methods[n]);return e},ttq.load=function(e,n){var i="https://analytics.tiktok.com/i18n/pixel/events.js";ttq._i=ttq._i||{},ttq._i[e]=[],ttq._i[e]._u=i,ttq._t=ttq._t||{},ttq._t[e]=+new Date,ttq._o=ttq._o||{},ttq._o[e]=n||{};var o=document.createElement("script");o.type="text/javascript",o.defer=true,o.src=i+"?sdkid="+e+"&lib="+t;var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(o,a);};
#     ttq.load('C1I87V1T0U322RQPSRKG');
#     ttq.page();
#   }(window, document, 'ttq');
#   </script><script id="radware">(function (w, d, e, u, c, g, a, b) {
#         w['SSJSConnectorObj'] = w['SSJSConnectorObj'] || {
#           ss_cid: c,
#           domain_info: 'auto',
#         };
#         w[g] = function (i, j) {
#           w['SSJSConnectorObj'][i] = j;
#         };
#         a = d.createElement(e);
#         a.async = true;
#         a.src = u;
#         b = d.getElementsByTagName(e)[0];
#         b.parentNode.insertBefore(a, b);
#       })(
#         window,
#         document,
#         'script',
#         'https://cdn.perfdrive.com/aperture/aperture.js',
#         'bna1',
#         'ssConf'
#       );
#       ssConf('c1', 'https://cas.avalon.perfdrive.com');</script><script>(function(d,c){var s=d.createElement('script');s.type='text/javascript';s.defer=!0;s.src='https://magalu-ads-px.luizalabs.com/magaluads-0.2.0.min.js';s.onload=c;d.head.appendChild(s);})(document,function(){magaluads.init('magazine_ecomm');});</script><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0 maximum-scale=1.0"/><link data-testid="link-0" rel="canonical" href="https://www.magazineluiza.com.br/busca/smartphone+128gb/"/><link data-testid="link-1" rel="alternate" media="only screen and (max-width: 640px)" href="https://m.magazineluiza.com.br/busca/smartphone+128gb/"/><title data-testid="meta-title">smartphone 128gb em Promoção no Magazine Luiza</title><meta data-testid="meta-description" name="description" content="Procurando por smartphone 128gb? Confira as ofertas que a Magalu separou para você. Facilidade no pagamento e entrega rápida. Vem ser feliz!"/><meta name="next-head-count" content="15"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/mixer/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script src="/mixer/_next/static/chunks/webpack-f7a47a5420bfb49b.js" defer=""></script><script src="/mixer/_next/static/chunks/framework-a78051e383c5165f.js" defer=""></script><script src="/mixer/_next/static/chunks/main-babd0d31cb19eb15.js" defer=""></script><script src="/mixer/_next/static/chunks/pages/_app-add2a49f0f67b85a.js" defer=""></script><script src="/mixer/_next/static/chunks/2edb282b-5e499321bfa6e8ba.js" defer=""></script><script src="/mixer/_next/static/chunks/6863-aeaba09c6e8a16a7.js" defer=""></script><script src="/mixer/_next/static/chunks/6791-5e38645efd07f2c3.js" defer=""></script><script src="/mixer/_next/static/chunks/4961-bb7f05b13848ab89.js" defer=""></script><script src="/mixer/_next/static/chunks/8016-71cdaa4151cd11fb.js" defer=""></script><script src="/mixer/_next/static/chunks/6272-b543cfb5b62cf918.js" defer=""></script><script src="/mixer/_next/static/chunks/2909-309145769228aa76.js" defer=""></script><script src="/mixer/_next/static/chunks/6208-ea6d163907ddbf0a.js" defer=""></script><script src="/mixer/_next/static/chunks/1099-5308c2804491e897.js" defer=""></script><script src="/mixer/_next/static/chunks/651-ea9638c83be249fa.js" defer=""></script><script src="/mixer/_next/static/chunks/5040-9075bc2ed8460701.js" defer=""></script><script src="/mixer/_next/static/chunks/6160-ce6a28c2536a9177.js" defer=""></script><script src="/mixer/_next/static/chunks/4022-3e1ae82a71a33f72.js" defer=""></script><script src="/mixer/_next/static/chunks/334-66b3e0b27c5b63dd.js" defer=""></script><script src="/mixer/_next/static/chunks/9498-f4c574375aea1ce4.js" defer=""></script><script src="/mixer/_next/static/chunks/2699-8945e3b834cdfc77.js" defer=""></script><script src="/mixer/_next/static/chunks/2118-ecb3ed28550886e5.js" defer=""></script><script src="/mixer/_next/static/chunks/361-2aaf1a2a0ce8322b.js" defer=""></script><script src="/mixer/_next/static/chunks/6876-d5c34d9f156dd69c.js" defer=""></script><script src="/mixer/_next/static/chunks/5490-1595f48072365acb.js" defer=""></script><script src="/mixer/_next/static/chunks/5928-95ce000e2d15dff5.js" defer=""></script><script src="/mixer/_next/static/chunks/4490-ab59d07d88e5d26b.js" defer=""></script><script src="/mixer/_next/static/chunks/8114-600dcc82b3cb1655.js" defer=""></script><script src="/mixer/_next/static/chunks/235-cff5fcd2ed03ce3c.js" defer=""></script><script src="/mixer/_next/static/chunks/3279-71fe752c724873a3.js" defer=""></script><script src="/mixer/_next/static/chunks/3543-50e56651bbd26391.js" defer=""></script><script src="/mixer/_next/static/chunks/3895-e4f5f6041ed604e8.js" defer=""></script><script src="/mixer/_next/static/chunks/6844-be4be215969609d5.js" defer=""></script><script src="/mixer/_next/static/chunks/1049-6c010aeb28fb0c89.js" defer=""></script><script src="/mixer/_next/static/chunks/9538-fdf4 ...
# .dfqBDr *{margin:0;padding:0;outline:0;box-sizing:border-box;}/*!sc*/
# .dfqBDr body{margin:0;}/*!sc*/
# data-styled.g1[id="sc-bcXHqe"]{content:"dfqBDr,"}/*!sc*/
# .cDFTGQ{visibility:hidden;position:fixed;z-index:-1;}/*!sc*/
# data-styled.g2[id="sc-gswNZR"]{content:"cDFTGQ,"}/*!sc*/
# .jQWLDj{width:95;height:113;}/*!sc*/
# .IvQgr{color:#fff;fill:#fff;width:138px;height:30px;}/*!sc*/
# .hGcysA{width:24px;height:24px;}/*!sc*/
# .jezbej{color:#fefefe;fill:#fefefe;}/*!sc*/
# .fULaLy{color:#ffffff;fill:#ffffff;width:29px;height:25px;}/*!sc*/
# .fLDNZK{color:#bcbcbc;fill:#bcbcbc;width:20px;height:20px;}/*!sc*/
# .hpZRnC{color:#818181;fill:#818181;width:24px;height:24px;}/*!sc*/
# .jqYHaY{width:20px;height:20px;}/*!sc*/
# .egyRwi{color:transparent;fill:transparent;width:20px;height:20px;}/*!sc*/
# .eDwKNe{color:#a400e1;fill:#a400e1;width:24px;height:24px;}/*!sc*/
# .ceqlyG{color:#999;fill:#999;width:24px;height:24px;}/*!sc*/
# .Ecxsy{color:currentColor;fill:currentColor;width:24px;height:24px;}/*!sc*/
# data-styled.g3[id="sc-dkrFOg"]{content:"jQWLDj,IvQgr,hGcysA,jezbej,fULaLy,fLDNZK,hpZRnC,jqYHaY,egyRwi,eDwKNe,ceqlyG,Ecxsy,"}/*!sc*/
# .hhSPfq{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:44px;overflow:hidden;color:#010101;}/*!sc*/
# .gcxrmT{box-sizing:border-box;cursor:inherit;}/*!sc*/
# .kyQkxO{box-sizing:border-box;cursor:inherit;color:white;font-weight:700;font-size:12px;color:white;}/*!sc*/
# .iYOSEN{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:161%;overflow:hidden;color:#010101;}/*!sc*/
# .gboKZg{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:83%;overflow:hidden;color:#010101;}/*!sc*/
# .difBdZ{box-sizing:border-box;cursor:inherit;background-color:#eee;width:100%;height:75px;padding-top:6%;overflow:hidden;color:#010101;}/*!sc*/
# .jhYCOU{box-sizing:border-box;cursor:inherit;overflow-y:hidden;}/*!sc*/
# .pvUxA{box-sizing:border-box;cursor:inherit;text-align:justify;font-size:14px;color:#808080;font-weight:400;line-height:1.25;color:#808080;}/*!sc*/
# .dZeFaV{box-sizing:border-box;cursor:inherit;margin-bottom:16px;}/*!sc*/
# .dkftFw{box-sizing:border-box;cursor:inherit;margin-top:16px;margin-bottom:16px;margin-left:8px;margin-right:8px;}/*!sc*/
# .kASfGa{box-sizing:border-box;cursor:inherit;border-radius:4px;z-index:1;}/*!sc*/
# .cUcHAv{box-sizing:border-box;cursor:inherit;background-color:#0086ff;border-radius:4px;z-index:10;color:#ffffff;}/*!sc*/
# .eZMgoD{box-sizing:border-box;cursor:inherit;box-shadow:0px 2px 12px rgba(81,81,81,0.12);border-radius:4px;}/*!sc*/
# @media screen and (min-width:48em){.eZMgoD{box-shadow:0px 2px 12px rgba(81,81,81,0.12);}}/*!sc*/
# @media screen and (min-width:64em){.eZMgoD{box-shadow:unset;}}/*!sc*/
# @media screen and (min-width:72em){.eZMgoD{box-shadow:unset;}}/*!sc*/
# .blWoJz{box-sizing:border-box;cursor:inherit;font-size:18px;line-height:1;}/*!sc*/
# @media screen and (min-width:48em){.blWoJz{font-size:24px;}}/*!sc*/
# .fCaGZe{box-sizing:border-box;cursor:inherit;min-height:480px;}/*!sc*/
# .cnuOqV{box-sizing:border-box;cursor:inherit;background-color:#a400e1;color:#ffffff;}/*!sc*/
# .eChJEv{box-sizing:border-box;cursor:inherit;background-color:rgba(0,0,0,0.63);color:#ffffff;}/*!sc*/
# .iQVUSi{box-sizing:border-box;cursor:inherit;position:center;padding:16px;background-color:#f4f4f4;z-index:10;color:#010101;}/*!sc*/
# .iquycI{box-sizing:border-box;cursor:inherit;position:center;padding:unset;margin-top:4em;margin-bottom:4em;background-color:#f4f4f4;z-index:10;color:#010101;}/*!sc*/
# data-styled.g4[id="sc-hLBbgP"]{content:"hhSPfq,gcxrmT,kyQkxO,iYOSEN,gboKZg,difBdZ,jhYCOU,pvUxA,dZeFaV,dkftFw,kASfGa,cUcHAv,eZMgoD,blWoJz,fCaGZe,cnuOqV,eChJEv,iQVUSi,iquycI,"}/*!sc*/
# .eqEBYW{width:100%;min-height:100vh;display:grid;grid-template-columns:1fr minmax(auto,366px) minmax(auto,1000px) 1fr;grid-template-rows:auto auto auto auto auto auto auto;grid-template-areas:'header header header header' '. beforecontent beforecontent .' '. sideleft content .' '. aftercontent aftercontent .' 'footer footer footer footer';background-color:#fff;}/*!sc*/
# data-styled.g5[id="sc-a263dbe6-0"]{content:"eqEBYW,"}/*!sc*/
# @font-face{font-display:swap;font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto'),local('Roboto-Regular'),url('/mixer/assets/fonts/roboto-v20-latin-regular.woff2') format('woff2'),url('/mixer/assets/fonts/roboto-v20-latin-regular.woff') format('woff');}/*!sc*/
# @font-face{font-display:swap;font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url('/mixer/assets/fonts/roboto-v20-latin-500.woff2') format('woff2'),url('/mixer/assets/fonts/roboto-v20-latin-500.woff') format('woff');}/*!sc*/
# @font-face{font-display:swap;font-family:'Roboto';font-style:normal;font-weight:700;src:local('Roboto Bold'),local('Roboto-Bold'),url('/mixer/assets/fonts/roboto-v20-latin-700.woff2') format('woff2'),url('/mixer/assets/fonts/roboto-v20-latin-700.woff') format('woff');}/*!sc*/
# html,body{margin:unset;background-color:#f4f4f4;color:#404040;font-family:'Roboto',sans-serif;}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# *,*:before,*:after{box-sizing:border-box;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# body{position:relative;}/*!sc*/
# data-styled.g6[id="sc-global-BFcNO1"]{content:"sc-global-BFcNO1,"}/*!sc*/
# .fWvbIU{margin:0px;max-height:44px;}/*!sc*/
# .fOXryo{padding:0 8px;}/*!sc*/
# .jzcpYb{line-height:normal;padding:9px 14px;text-align:left;margin-top:30px;}/*!sc*/
# .gyVTIL{line-height:normal;padding:9px 14px;text-align:left;margin-bottom:30px;}/*!sc*/
# .koHJnT{margin:8px;}/*!sc*/
# data-styled.g7[id="sc-eDvSVe"]{content:"fWvbIU,fOXryo,jzcpYb,gyVTIL,koHJnT,"}/*!sc*/
# .jEMyrg{position:relative;cursor:pointer;}/*!sc*/
# .jEMyrg div,.jEMyrg iframe{position:absolute;top:0;left:0;width:100% !important;height:100% !important;}/*!sc*/
# data-styled.g8[id="sc-jSUZER"]{content:"jEMyrg,"}/*!sc*/
# .fvAzpR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#fff;}/*!sc*/
# .bgNHmD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dyxqyk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;font-size:12px;font-weight:normal;}/*!sc*/
# @media screen and (min-width:48em){.dyxqyk{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# @media screen and (min-width:64em){.dyxqyk{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# .btfvRE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:2px;margin-right:2px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .harUJN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#0086ff;margin:0;}/*!sc*/
# .gCvLbz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:8px;margin-top:8px;cursor:pointer;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-left:8px;padding-right:8px;gap:0;}/*!sc*/
# .DmsHv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:8px;}/*!sc*/
# .kqaANz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:0;row-gap:8px;}/*!sc*/
# .eDZzwR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:32px;}/*!sc*/
# .fmKVud{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-weight:500;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:4px;row-gap:8px;}/*!sc*/
# .RVBmN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;text-align:initial;position:relative;padding-left:0;padding-right:0;padding-top:0;padding-bottom:0;width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;gap:0;row-gap:8px;}/*!sc*/
# .gPCKTA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;gap:4px;}/*!sc*/
# .cHoCxF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#fff;}/*!sc*/
# .floPyF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}/*!sc*/
# .hTIfiM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:space-between;-ms-flex-line-pack:space-between;align-content:space-between;}/*!sc*/
# .kMZcJF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:18px;margin-top:15px;}/*!sc*/
# .cpNtTu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (min-width:48em){}/*!sc*/
# @media screen and (min-width:64em){}/*!sc*/
# @media screen and (min-width:72em){.cpNtTu{padding-left:16px;}}/*!sc*/
# .bmTdkD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-left:10px;}/*!sc*/
# .emWzYP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background-color:#ffffff;}/*!sc*/
# .jVuSZM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px;}/*!sc*/
# .cHfyVv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:center;z-index:1060;}/*!sc*/
# .ftuwtI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:space-evenly;-webkit-justify-content:space-evenly;-ms-flex-pack:space-evenly;justify-content:space-evenly;left:0;line-height:1.6;padding:16px;position:fixed;top:0;width:100%;z-index:1050;}/*!sc*/
# @media screen and (min-width:48em){.ftuwtI{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;top:inherit;}}/*!sc*/
# @media screen and (min-width:64em){.ftuwtI{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;top:inherit;}}/*!sc*/
# .dnxaJC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:90%;}/*!sc*/
# @media screen and (min-width:48em){.dnxaJC{width:60%;}}/*!sc*/
# @media screen and (min-width:64em){.dnxaJC{width:60%;}}/*!sc*/
# .cRiqUS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin-top:4px;}/*!sc*/
# @media screen and (min-width:48em){.cRiqUS{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-top:0;}}/*!sc*/
# @media screen and (min-width:64em){.cRiqUS{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-top:0;}}/*!sc*/
# data-styled.g13[id="sc-jrcTuL"]{content:"fvAzpR,bgNHmD,dyxqyk,btfvRE,harUJN,gCvLbz,DmsHv,kqaANz,eDZzwR,fmKVud,RVBmN,gPCKTA,cHoCxF,floPyF,hTIfiM,kMZcJF,cpNtTu,bmTdkD,emWzYP,jVuSZM,cHfyVv,ftuwtI,dnxaJC,cRiqUS,"}/*!sc*/
# .eZcBMs{-webkit-flex:1;-ms-flex:1;flex:1;color:inherit;position:initial;left:initial;-webkit-transform:initial;-ms-transform:initial;transform:initial;}/*!sc*/
# .hOWpab{font-size:16px;font-weight:500;color:#404040;}/*!sc*/
# .bTxmKF{font-size:16px;-webkit-flex:1;-ms-flex:1;flex:1;color:inherit;position:initial;left:initial;-webkit-transform:initial;-ms-transform:initial;transform:initial;}/*!sc*/
# .gwZjgC{color:#8c8c8c;margin-left:4px;}/*!sc*/
# .eRwneT{font-size:16px;text-align:initial;-webkit-flex:1;-ms-flex:1;flex:1;color:inherit;position:initial;left:initial;-webkit-transform:initial;-ms-transform:initial;transform:initial;}/*!sc*/
# .kUzNIF{color:#808080;margin-left:4px;}/*!sc*/
# .eKKext{font-size:12px;color:#404040;}/*!sc*/
# .jEugou{color:inherit;}/*!sc*/
# .dWUthx{color:#404040;font-size:24px;font-weight:700;padding-right:4px;}/*!sc*/
# .iphQIY{color:#404040;font-size:24px;}/*!sc*/
# .gfGDOa{font-size:13px;font-weight:400;line-height:1.25;color:#404040;}/*!sc*/
# .gcLiKJ{font-size:12px;line-height:1;color:#808080;}/*!sc*/
# @media screen and (min-width:48em){.gcLiKJ{font-size:14px;}}/*!sc*/
# .jDmBNY{color:#404040;}/*!sc*/
# .szpaO{margin-top:8px;font-size:12px;font-weight:400;line-height:1;color:#404040;}/*!sc*/
# @media screen and (min-width:48em){.szpaO{font-size:14px;line-height:1.25;}}/*!sc*/
# .cOQarI{font-size:14px;font-weight:500;color:#bcbcbc;}/*!sc*/
# .kRkdZt{color:#fefefe;font-weight:700;font-size:18px;line-height:1.25;}/*!sc*/
# .gPrHYA{font-size:12px;color:#404040;}/*!sc*/
# @media screen and (min-width:48em){.gPrHYA{font-size:12px;}}/*!sc*/
# @media screen and (min-width:64em){.gPrHYA{font-size:14px;}}/*!sc*/
# @media screen and (min-width:72em){.gPrHYA{font-size:14px;}}/*!sc*/
# .cckhHA{color:#fefefe;font-size:12px;font-weight:700;}/*!sc*/
# @media screen and (min-width:48em){.cckhHA{font-size:16px;}}/*!sc*/
# @media screen and (min-width:64em){.cckhHA{font-size:16px;}}/*!sc*/
# .dWVrmG{background-color:transparent;font-size:12px;font-weight:700;color:#404040;}/*!sc*/
# @media screen and (min-width:48em){.dWVrmG{font-size:16px;}}/*!sc*/
# @media screen and (min-width:64em){.dWVrmG{font-size:16px;}}/*!sc*/
# data-styled.g14[id="sc-kDvujY"]{content:"eZcBMs,hOWpab,bTxmKF,gwZjgC,eRwneT,kUzNIF,eKKext,jEugou,dWUthx,iphQIY,gfGDOa,gcLiKJ,jDmBNY,szpaO,cOQarI,kRkdZt,gPrHYA,cckhHA,dWVrmG,"}/*!sc*/
# .eofTlx{-webkit-animation:hUniol 0.3s linear;animation:hUniol 0.3s linear;-webkit-overflow-scrolling:touch;position:absolute;width:100%;height:100%;top:0;left:0;bottom:0;right:0;cursor:pointer;}/*!sc*/
# data-styled.g15[id="sc-ipEyDJ"]{content:"eofTlx,"}/*!sc*/
# .iVaVyi{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:fixed;width:100%;height:100%;top:0;left:0;bottom:0;right:0;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;visibility:hidden;}/*!sc*/
# data-styled.g16[id="sc-csuSiG"]{content:"iVaVyi,"}/*!sc*/
# .bUCouD{overflow-x:auto;margin:15px;-webkit-animation:hUniol 0.3s ease-in;animation:hUniol 0.3s ease-in;width:85%;max-width:calc(1366px - 15%);border-radius:6px;}/*!sc*/
# data-styled.g18[id="sc-bqWxrE"]{content:"bUCouD,"}/*!sc*/
# .dzFcdB{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g19[id="sc-ksBlkl"]{content:"dzFcdB,"}/*!sc*/
# .ioCAZV{padding-right:8px;margin-left:auto;cursor:pointer;}/*!sc*/
# data-styled.g20[id="sc-hBxehG"]{content:"ioCAZV,"}/*!sc*/
# .gYRMlH{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .cxkrVt{-webkit-text-decoration:none;text-decoration:none;min-height:56px;}/*!sc*/
# .fUqWnR{-webkit-text-decoration:none;text-decoration:none;color:#404040;background-color:transparent;min-height:32px;}/*!sc*/
# data-styled.g21[id="sc-fnGiBr"]{content:"gYRMlH,cxkrVt,fUqWnR,"}/*!sc*/
# .kepfMk{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;text-align:justify;text-align-last:left;}/*!sc*/
# data-styled.g23[id="sc-bjfHbI"]{content:"kepfMk,"}/*!sc*/
# .kNKHKj{cursor:pointer;}/*!sc*/
# data-styled.g25[id="sc-dIfARi"]{content:"kNKHKj,"}/*!sc*/
# .ZbaEi{overflow:hidden;-webkit-transition:max-height 0.3s ease-out;transition:max-height 0.3s ease-out;max-height:100%;}/*!sc*/
# .dETsGm{overflow:hidden;-webkit-transition:max-height 0.3s ease-out;transition:max-height 0.3s ease-out;max-height:0px;}/*!sc*/
# data-styled.g26[id="sc-hHTYSt"]{content:"ZbaEi,dETsGm,"}/*!sc*/
# .egNKll{position:relative;width:100%;height:100%;border:none;cursor:pointer;background:none;-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# .egNKll:disabled{opacity:0.5;}/*!sc*/
# .egNKll:hover:not(:disabled){-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}/*!sc*/
# data-styled.g27[id="sc-dmctIk"]{content:"egNKll,"}/*!sc*/
# .ggbRTN{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g31[id="sc-iveFHk"]{content:"ggbRTN,"}/*!sc*/
# .cjBXjP{-webkit-text-decoration:none;text-decoration:none;font-size:14px;color:#bcbcbc;}/*!sc*/
# data-styled.g33[id="sc-lllmON"]{content:"cjBXjP,"}/*!sc*/
# .hlhVrk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g35[id="sc-gikAfH"]{content:"hlhVrk,"}/*!sc*/
# .NwHDg{cursor:not-allowed;font-weight:500;text-align:center;margin-top:1px;grid-area:label;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}/*!sc*/
# .NwHDg small{font-weight:500;text-transform:none;display:block;}/*!sc*/
# .eLmReH{cursor:pointer;font-weight:500;text-align:center;margin-top:1px;grid-area:label;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}/*!sc*/
# .eLmReH small{font-weight:500;text-transform:none;display:block;}/*!sc*/
# data-styled.g37[id="sc-bYMpWt"]{content:"NwHDg,eLmReH,"}/*!sc*/
# .jkDbOX{cursor:not-allowed;font-family:'Roboto',sans-serif;outline:none;border:none;border-radius:4px;padding:0px 15px;width:100%;display:grid;grid-column:unset;grid-template-areas:'label';grid-template-columns:auto;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-text-decoration:none;text-decoration:none;height:44px;min-width:140px;font-size:14px;background-color: #0086ff;color:#fefefe;width:medium;height:medium;}/*!sc*/
# .jkDbOX .sc-bYMpWt{text-transform:uppercase;}/*!sc*/
# .jkDbOX svg{fill:#fefefe;}/*!sc*/
# .jkDbOX:hover{background-color: #005eb2;color:#fefefe;}/*!sc*/
# .jkDbOX,.jkDbOX:hover{background-color:#e5e5e5;color:#808080;}/*!sc*/
# .jkDbOX svg,.jkDbOX:hover svg{fill:#808080;}/*!sc*/
# .iwnAUg{cursor:pointer;font-family:'Roboto',sans-serif;outline:none;border:none;border-radius:4px;padding:0px 15px;width:auto;display:grid;grid-column:unset;grid-template-areas:'label';grid-template-columns:'';grid-gap:0px 0px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-text-decoration:none;text-decoration:none;height:44px;min-width:140px;font-size:14px;background-color:transparent;box-shadow:inset 0 0 0 1px #a400e1;color:#a400e1;width:medium;height:medium;}/*!sc*/
# .iwnAUg svg{fill:#a400e1;}/*!sc*/
# .iwnAUg:hover{box-shadow:inset 0 0 0 1px #6c0094;color:#6c0094;}/*!sc*/
# .iwnAUg:hover svg{fill:#6c0094;}/*!sc*/
# data-styled.g39[id="sc-ilhmMj"]{content:"jkDbOX,iwnAUg,"}/*!sc*/
# .iilPOm{width:100%;height:inherit;object-fit:contain;}/*!sc*/
# .bFQoJC{width:100%;height:inherit;object-fit:contain;border-radius:4px;}/*!sc*/
# .fSCGho{width:100%;height:inherit;object-fit:contain;max-height:90px;}/*!sc*/
# .kbrWIS{width:100%;height:inherit;object-fit:contain;max-height:25px;}/*!sc*/
# .emQVPS{width:100%;height:inherit;object-fit:contain;max-height:12px;}/*!sc*/
# data-styled.g40[id="sc-jIRcFI"]{content:"iilPOm,bFQoJC,fSCGho,kbrWIS,emQVPS,"}/*!sc*/
# .jZChDm{-webkit-transition:box-shadow ease 0.4s;transition:box-shadow ease 0.4s;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:grid;overflow:hidden;grid-template-areas:"image" "body";-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;border-radius:6px;}/*!sc*/
# .jZChDm:hover{box-shadow:0px 2px 12px rgba(81,81,81,0.12);}/*!sc*/
# data-styled.g41[id="sc-hhOBVt"]{content:"jZChDm,"}/*!sc*/
# .chrdoM{-webkit-appearance:none;-moz-appearance:none;appearance:none;background:transparent;width:20px;height:20px;outline:none;cursor:pointer;}/*!sc*/
# .chrdoM:not(:checked){border-radius:4px;border:2px solid #bcbcbc;}/*!sc*/
# .chrdoM:checked:after{content:url('...');position:absolute;width:20px;height:20px;background:#0086ff;border-radius:4px;box-sizing:border-box;}/*!sc*/
# .chrdoM:checked:disabled:after{background:#999;}/*!sc*/
# data-styled.g48[id="sc-iAEawV"]{content:"chrdoM,"}/*!sc*/
# .dMuOAr{display:grid;}/*!sc*/
# .dKlrlT{display:grid;margin-top:16px;margin-bottom:16px;margin-left:8px;margin-right:8px;row-gap:16px;}/*!sc*/
# .dHhozk{display:grid;gap:8px;}/*!sc*/
# .jdNdfB{display:grid;grid-gap:2px;}/*!sc*/
# @media screen and (min-width:48em){.jdNdfB{grid-gap:1px;}}/*!sc*/
# @media screen and (min-width:64em){.jdNdfB{grid-gap:1px;}}/*!sc*/
# .eqcIbq{display:grid;background-color:#a400e1;}/*!sc*/
# data-styled.g53[id="sc-bCfvAP"]{content:"dMuOAr,dKlrlT,dHhozk,jdNdfB,eqcIbq,"}/*!sc*/
# .iKioUi{display:grid;}/*!sc*/
# .iKioUi > *:nth-child(n + 11){display:none;overflow:hidden;max-height:0;}/*!sc*/
# data-styled.g54[id="sc-cOxWqc"]{content:"iKioUi,"}/*!sc*/
# .dpUMky{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;font-size:14px;}/*!sc*/
# .dpUMky:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .kPkrYL{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;margin-right:16px;font-size:14px;}/*!sc*/
# .kPkrYL:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .ceyxPQ{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#cce6f4;background-color:transparent;padding:0;font-size:12px;font-weight:700;}/*!sc*/
# .ceyxPQ:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#cce6f4;}/*!sc*/
# @media screen and (min-width:48em){.ceyxPQ{font-size:12px;font-weight:700;}}/*!sc*/
# @media screen and (min-width:64em){.ceyxPQ{font-size:12px;font-weight:700;}}/*!sc*/
# @media screen and (min-width:72em){.ceyxPQ{font-size:14px;font-weight:400;}}/*!sc*/
# .doAIBk{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:white;background-color:transparent;padding:0;font-size:12px;}/*!sc*/
# .doAIBk:hover{-webkit-text-decoration:underline;text-decoration:underline;color:white;}/*!sc*/
# .eUMXOl{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;margin-left:4px;margin-right:4px;font-size:14px;}/*!sc*/
# .eUMXOl:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .grNZgV{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ffffff;background-color:transparent;padding-left:10px;padding-right:10px;font-size:14px;}/*!sc*/
# .grNZgV:hover{-webkit-text-decoration:none;text-decoration:none;color:#ffffff;}/*!sc*/
# .fGjHgt{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:transparent;color:#404040;padding-left:8px;padding-right:8px;font-size:14px;}/*!sc*/
# .fGjHgt:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#404040;}/*!sc*/
# .ifyZsO{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#a400e1;background-color:transparent;font-size:14px;}/*!sc*/
# .ifyZsO:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#a400e1;}/*!sc*/
# .kDONIO{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ff8a00;background-color:transparent;font-size:14px;}/*!sc*/
# .kDONIO:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#ff8a00;}/*!sc*/
# .kjmzTS{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#00d604;background-color:transparent;font-size:14px;}/*!sc*/
# .kjmzTS:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#00d604;}/*!sc*/
# .dBzuIL{cursor:pointer;font-size:inherit;font-family:inherit;border:0;margin:0;overflow:visible;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#0086ff;background-color:transparent;padding-left:0;padding-right:0;font-weight:500;font-size:16px;}/*!sc*/
# .dBzuIL:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#0086ff;}/*!sc*/
# .bzzsSW{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding:0;font-size:14px;}/*!sc*/
# .bzzsSW:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .kFuGJF{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding-left:10px;padding-right:10px;font-size:14px;}/*!sc*/
# .kFuGJF:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .cjwWVo{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding:0;padding-left:4px;font-size:14px;}/*!sc*/
# .cjwWVo:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .eVKpng{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fefefe;background-color:transparent;padding-left:4px;font-size:14px;}/*!sc*/
# .eVKpng:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fefefe;}/*!sc*/
# .iReXOq{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:yellow;background-color:transparent;font-size:12px;font-weight:700;}/*!sc*/
# .iReXOq:hover{-webkit-text-decoration:underline;text-decoration:underline;color:yellow;}/*!sc*/
# @media screen and (min-width:48em){.iReXOq{font-size:16px;}}/*!sc*/
# @media screen and (min-width:64em){.iReXOq{font-size:16px;}}/*!sc*/
# data-styled.g55[id="sc-AHaJN"]{content:"dpUMky,kPkrYL,ceyxPQ,doAIBk,eUMXOl,grNZgV,fGjHgt,ifyZsO,kDONIO,kjmzTS,dBzuIL,bzzsSW,kFuGJF,cjwWVo,eVKpng,iReXOq,"}/*!sc*/
# .cjVUwh{height:1px;width:100%;border:none;background-color:#ececec;}/*!sc*/
# data-styled.g63[id="sc-eJDSGI"]{content:"cjVUwh,"}/*!sc*/
# .fPchIw{border:1px solid;border-color:#ececec;border-radius:4px;width:100%;padding:8px;line-height:1.4;font-size:14px;}/*!sc*/
# .fPchIw::-webkit-input-placeholder{color:#999;}/*!sc*/
# .fPchIw::-moz-placeholder{color:#999;}/*!sc*/
# .fPchIw:-ms-input-placeholder{color:#999;}/*!sc*/
# .fPchIw::placeholder{color:#999;}/*!sc*/
# data-styled.g71[id="sc-GhhNo"]{content:"fPchIw,"}/*!sc*/
# .bHwRQk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# .bHwRQk label{margin-right:10px;font-weight:700;font-size:12px;}/*!sc*/
# .bHwRQk select{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:block;background:transparent;cursor:pointer;border:1px solid #bcbcbc;font-size:12px;padding:8px 32px 8px 12px;}/*!sc*/
# .bHwRQk select:focus{outline:none;background:#f4f4f4;}/*!sc*/
# .bHwRQk select::-ms-expand{display:none;}/*!sc*/
# .bHwRQk svg{outline:none;pointer-events:none;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;margin-left:-32px;}/*!sc*/
# data-styled.g77[id="sc-jNJNQp"]{content:"bHwRQk,"}/*!sc*/
# .koyLjS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;height:100%;}/*!sc*/
# data-styled.g78[id="sc-hlLBRy"]{content:"koyLjS,"}/*!sc*/
# .gkNZFU{position:relative;width:100%;height:100%;max-width:60px;max-height:46px;border:none;cursor:pointer;background:none;-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# .gkNZFU:disabled{opacity:0.5;}/*!sc*/
# .gkNZFU:hover:not(:disabled){-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}/*!sc*/
# data-styled.g79[id="sc-eKJbhj"]{content:"gkNZFU,"}/*!sc*/
# .uHDUk{background-color:#db44a7;color:#ffffff;position:absolute;right:0;bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:28px;width:28px;border-radius:50%;border:3px solid #0086ff;font-size:12px;font-weight:bold;}/*!sc*/
# .jlGgkH{background-color:#58c22e;color:#ffffff;position:absolute;right:0;bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:28px;width:28px;border-radius:50%;border:3px solid #0086ff;font-size:12px;font-weight:bold;}/*!sc*/
# data-styled.g80[id="sc-bTTELM"]{content:"uHDUk,jlGgkH,"}/*!sc*/
# .flOMoP{-webkit-appearance:none;-moz-appearance:none;appearance:none;background:transparent;width:20px;height:20px;border:2px solid #bcbcbc;border-radius:50%;cursor:pointer;}/*!sc*/
# .flOMoP:checked{border-color:#0086ff;}/*!sc*/
# .flOMoP:checked:before{content:'';display:block;position:relative;left:50%;top:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);width:10px;height:10px;border-radius:50%;background:#0086ff;}/*!sc*/
# data-styled.g83[id="sc-dsHJmm"]{content:"flOMoP,"}/*!sc*/
# .ceqVAx{float:left;height:5px;position:relative;width:100%;overflow:hidden;border:none;background-image:linear-gradient( to right, #ffff4a 0, #fcd000 4%, #ffc112 8%, #ffc112 11%, #ff8a00 16%, #ff5f5f 22%, #ff253a 28%, #ff37a8 37%, #c739ff 49%, #a400e1 56%, #2eceff 72%, #0086ff 80%, #72f772 94%, #00d604 );}/*!sc*/
# data-styled.g84[id="sc-cZFQFd"]{content:"ceqVAx,"}/*!sc*/
# .bYQtce{height:24px;}/*!sc*/
# data-styled.g85[id="sc-jTjUTQ"]{content:"bYQtce,"}/*!sc*/
# .jnffmT{width:100%;}/*!sc*/
# data-styled.g86[id="sc-jRwbcX"]{content:"jnffmT,"}/*!sc*/
# .dmQVRl{background-color:#f4f4f4;position:absolute;height:3px;width:100%;}/*!sc*/
# data-styled.g87[id="sc-fvEvSO"]{content:"dmQVRl,"}/*!sc*/
# .cHlyya{position:absolute;height:3px;}/*!sc*/
# data-styled.g88[id="sc-fcCDlF"]{content:"cHlyya,"}/*!sc*/
# .lmfxaK{pointer-events:none;position:absolute;height:0;width:100%;outline:none;z-index:1040;}/*!sc*/
# .lmfxaK,.lmfxaK::-webkit-slider-thumb{-webkit-appearance:none;-webkit-tap-highlight-color:transparent;}/*!sc*/
# .lmfxaK::-webkit-slider-thumb{background-color:#fff;border:1px solid #ededed;border-radius:50%;box-shadow:0 0 2px 0 rgba(0,0,0,.08),0 4px 16px 0 rgba(0,0,0,.16);cursor:pointer;height:24px;width:24px;margin-top:4px;pointer-events:all;position:relative;}/*!sc*/
# .lmfxaK::-moz-range-thumb{background-color:#fff;border:1px solid #ededed;border-radius:50%;box-shadow:0 0 2px 0 rgba(0,0,0,.08),0 4px 16px 0 rgba(0,0,0,.16);cursor:pointer;height:24px;width:24px;margin-top:4px;pointer-events:all;position:relative;}/*!sc*/
# .cAYlkD{pointer-events:none;position:absolute;height:0;width:100%;outline:none;z-index:1050;}/*!sc*/
# .cAYlkD,.cAYlkD::-webkit-slider-thumb{-webkit-appearance:none;-webkit-tap-highlight-color:transparent;}/*!sc*/
# .cAYlkD::-webkit-slider-thumb{background-color:#fff;border:1px solid #ededed;border-radius:50%;box-shadow:0 0 2px 0 rgba(0,0,0,.08),0 4px 16px 0 rgba(0,0,0,.16);cursor:pointer;height:24px;width:24px;margin-top:4px;pointer-events:all;position:relative;}/*!sc*/
# .cAYlkD::-moz-range-thumb{background-color:#fff;border:1px solid #ededed;border-radius:50%;box-shadow:0 0 2px 0 rgba(0,0,0,.08),0 4px 16px 0 rgba(0,0,0,.16);cursor:pointer;height:24px;width:24px;margin-top:4px;pointer-events:all;position:relative;}/*!sc*/
# data-styled.g89[id="sc-GKYbw"]{content:"lmfxaK,cAYlkD,"}/*!sc*/
# .kjmZdM{position:relative;margin-top:-25px;width:55px;height:40px;position:absolute;}/*!sc*/
# @media screen and (min-width:48em){.kjmZdM{width:55px;height:40px;}}/*!sc*/
# data-styled.g98[id="sc-fHSyak"]{content:"kjmZdM,"}/*!sc*/
# .domATk{background-color:#fff;}/*!sc*/
# data-styled.g99[id="sc-dubCtV"]{content:"domATk,"}/*!sc*/
# ...
# data-styled.g496[id="sc-jYECHi"]{content:"inRywI,"}/*!sc*/
# .ejckG{list-style:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;max-width:620px;}/*!sc*/
# data-styled.g497[id="sc-ggxSZb"]{content:"ejckG,"}/*!sc*/
# .jxPWPD{width:35px;}/*!sc*/
# data-styled.g498[id="sc-cVKHio"]{content:"jxPWPD,"}/*!sc*/
# .iFZUKM{padding:10px 0;}/*!sc*/
# data-styled.g500[id="sc-eHzXwO"]{content:"iFZUKM,"}/*!sc*/
# .cHyOqM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-bottom:16px;}/*!sc*/
# data-styled.g501[id="sc-PtnOH"]{content:"cHyOqM,"}/*!sc*/
# .jHkVhf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;list-style:none;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;max-width:990px;min-width:300px;}/*!sc*/
# data-styled.g502[id="sc-vKiki"]{content:"jHkVhf,"}/*!sc*/
# .jgLrbO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;max-width:120px;}/*!sc*/
# .jgLrbO > *:not(:first-child){margin-left:8px;}/*!sc*/
# data-styled.g503[id="sc-dUFyKH"]{content:"jgLrbO,"}/*!sc*/
# .fWpUbG{max-width:70px;font-size:12px;color:#fefefe;}/*!sc*/
# data-styled.g504[id="sc-eIlWkk"]{content:"fWpUbG,"}/*!sc*/
# .iGVJMa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g508[id="sc-imTPag"]{content:"iGVJMa,"}/*!sc*/
# .bNsLsR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;list-style:none;width:100%;max-width:990px;}/*!sc*/
# data-styled.g509[id="sc-wtwbJ"]{content:"bNsLsR,"}/*!sc*/
# .iGDWrn{padding:10px;color:#fefefe;font-size:14px;font-weight:400;}/*!sc*/
# data-styled.g511[id="sc-fqLacr"]{content:"iGDWrn,"}/*!sc*/
# .bnwymw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-writing-mode:vertical-lr;-ms-writing-mode:tb;writing-mode:vertical-lr;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-align-content:flex-start;-ms-flex-line-pack:start;align-content:flex-start;max-height:270px;line-height:12px;}/*!sc*/
# .bnwymw .sc-ihhmKJ{font-size:12px;color:#aad0e6;}/*!sc*/
# data-styled.g512[id="sc-jxoWcP"]{content:"bnwymw,"}/*!sc*/
# .dUNdhv{list-style:none;-webkit-writing-mode:horizontal-tb;-ms-writing-mode:lr;writing-mode:horizontal-tb;padding:1px 0px;}/*!sc*/
# data-styled.g513[id="sc-efhLOa"]{content:"dUNdhv,"}/*!sc*/
# .jYNwkb:not(:first-child){margin-left:12px;}/*!sc*/
# data-styled.g514[id="sc-chjvzV"]{content:"eJeAYA,jYNwkb,"}/*!sc*/
# .XLPbR{width:auto;}/*!sc*/
# data-styled.g516[id="sc-bMBftP"]{content:"XLPbR,"}/*!sc*/
# .laXeBX{padding:4px 16px;color:#999;font-size:12px;}/*!sc*/
# data-styled.g517[id="sc-hJPEDW"]{content:"laXeBX,"}/*!sc*/
# .hLPPBk{color:#999;}/*!sc*/
# data-styled.g518[id="sc-fLRopR"]{content:"hLPPBk,"}/*!sc*/
# .geXeHK{padding:10px;color:#fefefe;}/*!sc*/
# data-styled.g520[id="sc-kTuxuz"]{content:"geXeHK,"}/*!sc*/
# .iIzPLW{margin-bottom:10px;line-height:24px;font-size:24px;}/*!sc*/
# data-styled.g521[id="sc-fBnnfK"]{content:"iIzPLW,"}/*!sc*/
# .bGwRkU{margin-bottom:10px;font-size:12px;}/*!sc*/
# data-styled.g522[id="sc-kJHwSc"]{content:"bGwRkU,"}/*!sc*/
# .FWDsc{list-style:none;}/*!sc*/
# data-styled.g523[id="sc-kvhKsl"]{content:"FWDsc,"}/*!sc*/
# .kfKjbv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:20px;}/*!sc*/
# data-styled.g524[id="sc-jxfubC"]{content:"kfKjbv,"}/*!sc*/
# .kykojR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;background-color:#0086ff;}/*!sc*/
# .kykojR #seloEbit > img{height:40px;width:auto;margin-right:16px;}/*!sc*/
# data-styled.g526[id="sc-cYTGjc"]{content:"kykojR,"}/*!sc*/
# .ejZvMi{background-color:#a400e1;}/*!sc*/
# data-styled.g556[id="sc-gKAPXn"]{content:"ejZvMi,"}/*!sc*/
# .hjTRwY{color:#fefefe;font-size:12px;text-align:center;padding-top:12px;}/*!sc*/
# data-styled.g557[id="sc-bstFIy"]{content:"hjTRwY,"}/*!sc*/
# .gFUvjj{cursor:pointer;}/*!sc*/
# data-styled.g559[id="sc-frJOEA"]{content:"gFUvjj,"}/*!sc*/
# .jbukvl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:16px 2em;}/*!sc*/
# data-styled.g560[id="sc-fVuMRb"]{content:"jbukvl,"}/*!sc*/
# .hatYag{max-width:109px;max-height:20px;}/*!sc*/
# data-styled.g561[id="sc-DnCCm"]{content:"hatYag,"}/*!sc*/
# .jqVXkM{background-color:#f4f4f4;width:20px;height:20px;border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .jqVXkM > svg{width:12px;}/*!sc*/
# data-styled.g566[id="sc-hWTqMA"]{content:"jqVXkM,"}/*!sc*/
# .dquIMu{min-height:83px;border-top-left-radius:4px;border-top-right-radius:4px;grid-template-columns:1fr 4fr 1fr;}/*!sc*/
# @media screen and (min-width:64em){.dquIMu{border-radius:4px;}}/*!sc*/
# @media screen and (min-width:64em){.dquIMu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:80px;}}/*!sc*/
# .fpMzPi{min-height:83px;grid-template-columns:1fr 4fr 1fr;}/*!sc*/
# @media screen and (min-width:64em){.fpMzPi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:80px;}}/*!sc*/
# data-styled.g567[id="sc-hItEmJ"]{content:"dquIMu,fpMzPi,"}/*!sc*/
# .hRPjN{margin-top:14px;margin-left:10px;}/*!sc*/
# @media screen and (min-width:72em){.hRPjN{margin-top:0;}}/*!sc*/
# data-styled.g568[id="sc-gKrnWa"]{content:"hRPjN,"}/*!sc*/
# @media screen and (min-width:48em){.lcFuhS{-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;width:100%;}}/*!sc*/
# data-styled.g569[id="sc-gvRBwj"]{content:"lcFuhS,"}/*!sc*/
# @media screen and (min-width:64em){.fERhXY{margin:1em 16px 1em auto;min-width:269px;}.fERhXY > p{display:none;}.fERhXY > div{padding:unset;}}/*!sc*/
# data-styled.g570[id="sc-hhNnGo"]{content:"fERhXY,"}/*!sc*/
# .cOHDSS{width:75px;max-height:87px;margin-top:-5px;}/*!sc*/
# data-styled.g571[id="sc-gTnBgx"]{content:"cOHDSS,"}/*!sc*/
# @media screen and (min-width:64em){.iYWngN{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}}/*!sc*/
# data-styled.g572[id="sc-dxQQIp"]{content:"iYWngN,"}/*!sc*/
# @media screen and (min-width:64em){.iozEjq{height:32px;width:auto;}}/*!sc*/
# data-styled.g573[id="sc-jvfpSw"]{content:"iozEjq,"}/*!sc*/
# .jSheOr{text-align:center;margin-top:8px;}/*!sc*/
# .ckuiqd{text-align:center;margin-top:8px;font-size:12px;text-align:left;width:190px;}/*!sc*/
# @media screen and (min-width:64em){.ckuiqd{font-size:16px;width:100%;}}/*!sc*/
# data-styled.g574[id="sc-bYdiNP"]{content:"jSheOr,ckuiqd,"}/*!sc*/
# .eiCgWg{padding:0 14px 14px 14px;}/*!sc*/
# .eiCgWg img{width:100% !important;height:auto !important;}/*!sc*/
# .eiCgWg p{margin-block-start:1em;margin-block-end:1em;line-height:20px;}/*!sc*/
# .eiCgWg a{color:#0086ff;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g576[id="sc-fJcvgl"]{content:"eiCgWg,"}/*!sc*/
# .kvIDOZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g577[id="sc-qVkRw"]{content:"kvIDOZ,"}/*!sc*/
# .dShhhJ{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;}/*!sc*/
# @media screen and (min-width:64em){.dShhhJ{width:calc(25% - 7px);}.dShhhJ:not(:last-child){margin-right:28px;}}/*!sc*/
# data-styled.g587[id="sc-dvQGHj"]{content:"dShhhJ,"}/*!sc*/
# .duRDWX{background-color:#fff;border-top:1px solid #eee;display:grid;padding:16px;width:100%;justify-items:left;padding:16px 0px;}/*!sc*/
# data-styled.g588[id="sc-ejxegM"]{content:"duRDWX,"}/*!sc*/
# .eTwPAc{width:100%;}/*!sc*/
# data-styled.g589[id="sc-hIsuHl"]{content:"eTwPAc,"}/*!sc*/
# .cuMGPo{width:77px;border-radius:4px;border:1px solid #bcbcbc;min-width:300px;width:100%;height:auto;max-height:500px;object-fit:fill;}/*!sc*/
# @media screen and (min-width:64em){.cuMGPo{max-height:500px;min-height:168px;min-width:224px;height:calc( 900px / 4 );border-radius:8px;object-fit:cover;}}/*!sc*/
# data-styled.g590[id="sc-fVmuvm"]{content:"cuMGPo,"}/*!sc*/
# .kUnvhk{display:grid;grid-template-columns:auto 1fr;margin-top:0px;margin-top:10px;width:250px;}/*!sc*/
# @media screen and (min-width:72em){.kUnvhk{max-width:224px;}}/*!sc*/
# data-styled.g591[id="sc-juhKVL"]{content:"kUnvhk,"}/*!sc*/
# .YDFDS{color:#a400e1;font-weight:500;font-stretch:normal;font-style:normal;line-height:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;}/*!sc*/
# data-styled.g593[id="sc-bLaUG"]{content:"YDFDS,"}/*!sc*/
# .gMvjFJ{margin-top:8px;color:#404040;line-height:16px;display:-webkit-box;-webkit-line-clamp:3;-webkit-box-orient:vertical;overflow:hidden;font-weight:normal;font-stretch:normal;font-style:normal;font-size:12px;}/*!sc*/
# @media screen and (min-width:48em){.gMvjFJ{font-size:12px;}}/*!sc*/
# @media screen and (min-width:64em){.gMvjFJ{font-size:14px;}}/*!sc*/
# @media screen and (min-width:72em){.gMvjFJ{font-size:14px;}}/*!sc*/
# data-styled.g594[id="sc-jtiufx"]{content:"gMvjFJ,"}/*!sc*/
# .kjGpJh{position:relative;}/*!sc*/
# data-styled.g595[id="sc-ebbjQI"]{content:"kjGpJh,"}/*!sc*/
# .fHSgWx{border:none;color:#fefefe;cursor:pointer;}/*!sc*/
# data-styled.g614[id="sc-bnfANK"]{content:"fHSgWx,"}/*!sc*/
# .dGKUNm{width:100%;}/*!sc*/
# data-styled.g647[id="sc-hgiRw"]{content:"dGKUNm,"}/*!sc*/
# .fLizcn{color:#999;margin-right:auto;}/*!sc*/
# data-styled.g648[id="sc-cWiZSr"]{content:"fLizcn,"}/*!sc*/
# @-webkit-keyframes hUniol{from{opacity:0;}to{opacity:1;}}/*!sc*/
# @keyframes hUniol{from{opacity:0;}to{opacity:1;}}/*!sc*/
# data-styled.g930[id="sc-keyframes-hUniol"]{content:"hUniol,"}/*!sc*/
# @-webkit-keyframes ekuVYQ{from{opacity:0.5;-webkit-transform:scale(0.5);-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);}to{opacity:1;-webkit-transform:scale(0.5);-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}/*!sc*/
# @keyframes ekuVYQ{from{opacity:0.5;-webkit-transform:scale(0.5);-webkit-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);}to{opacity:1;-webkit-transform:scale(0.5);-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}/*!sc*/
# data-styled.g931[id="sc-keyframes-ekuVYQ"]{content:"ekuVYQ,"}/*!sc*/
# </style></head><body><div id="__next" data-reactroot=""><div class="sc-bcXHqe dfqBDr"><svg class="sc-gswNZR cDFTGQ"></svg><main class="sc-a263dbe6-0 eqEBYW"><noscript><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-BR2N" width="0" heigth="0" style="display:none;visibility:hidden"></iframe></noscript></noscript><section style="grid-area:header"><div data-testid="mod-taglessadunit" class="sc-eDvSVe fWvbIU"><div data-testid="tagless-adunit" id="/21908074511/Desktop/discovery_padrao/home/outros_banners/hypertop" width="100%" height="75px" overflow="hidden" class="sc-hLBbgP hhSPfq sc-jSUZER jEMyrg"></div></div><div class="sc-bRJSeJ fVaYlX"><header data-testid="header-elem" class="sc-kkCwLU bSfgrA"><div class="sc-bWWQYT gtZCRH"><a data-testid="logo-lu-magalu" href="https://www.magazineluiza.com.br/" role="link" aria-label="ir para página inicial" class="sc-AHaJN dpUMky sc-cTcUcm dyWycH sc-cTcUcm dyWycH" color="text.base" font-size="1"><svg data-testid="LogoMagaluIcon" viewBox="0 0 95 113" y="0" x="0" class="sc-dkrFOg jQWLDj"><image href="https://wx.mlcdn.com.br/site/desk/header/logo-lu.png" height="113" viewBox="0 0 95 113" width="95" y="0" x="0"></svg></a><a data-testid="logo-magalu" href="https://www.magazineluiza.com.br/" role="link" aria-label="ir para página inicial" class="sc-AHaJN kPkrYL sc-eyLAWx jblLGk sc-eyLAWx jblLGk" color="text.base" font-size="1"><svg data-testid="LogoMagaluIcon" viewBox="0 0 60 13" id="logo" fill="#fff" class="sc-dkrFOg IvQgr"><path d="M59.379 0.210938H58.0197C57.633 0.210938 57.3987 0.445293 57.3987 0.83198V4.85118C57.3987 6.32762 56.6018 7.15959 55.4945 7.15959C54.3286 7.15959 53.6724 6.40379 53.6724 4.94492V0.83198C53.6724 0.445293 53.438 0.210938 53.0514 0.210938H51.6921C51.3054 0.210938 51.071 0.445293 51.071 0.83198V5.13827C51.071 7.87437 52.4889 9.42698 54.6215 9.42698C55.9046 9.42698 56.8889 8.99928 57.592 8.1263L57.7092 8.67118C57.7853 9.02271 58.0197 9.21606 58.3888 9.21606H59.379C59.7656 9.21606 60 8.9817 60 8.59501V0.83198C60 0.445293 59.7715 0.210938 59.379 0.210938Z" fill="currentColor"></path><path d="M49.911 6.84906H47.4678C46.6124 6.84906 46.1671 6.40379 46.1671 5.54839V0.83198C46.1671 0.445293 45.9328 0.210938 45.5461 0.210938H44.1517C43.765 0.210938 43.5306 0.445293 43.5306 0.83198V5.87649C43.5306 7.95054 44.7903 9.21606 46.8702 9.21606H49.9168C50.3035 9.21606 50.5379 8.9817 50.5379 8.59501V7.47011C50.532 7.08342 50.2977 6.84906 49.911 6.84906Z" fill="currentColor"></path><path d="M10.3635 0.814404C10.3224 0.404281 10.1115 0.210938 9.72484 0.210938H8.69367C8.36557 0.210938 8.13122 0.345692 7.95545 0.638637L5.4537 4.86876L3.12772 0.638637C2.97539 0.345692 2.7176 0.210938 2.3895 0.210938H1.28217C0.895481 0.210937 0.684561 0.41014 0.643549 0.814404L0.00492948 8.57744C-0.0360828 9.00514 0.180696 9.21606 0.58496 9.21606H1.82705C2.21373 9.21606 2.44809 9.02271 2.46567 8.61259L2.73517 4.26529L4.22919 6.96038C4.38152 7.25333 4.63932 7.38808 4.96741 7.38808H5.82281C6.15091 7.38808 6.38527 7.27091 6.56103 6.96038L8.24839 4.07195L8.44174 8.61259C8.45931 9.02271 8.67609 9.21606 9.06278 9.21606H10.4045C10.8146 9.21606 11.0255 9.00514 10.9845 8.57744L10.3635 0.814404Z" fill="currentColor"></path><path d="M41.7261 0.21092H40.6598C40.2906 0.21092 40.0387 0.404264 39.9801 0.773374L39.9215 1.21865C39.3181 0.580031 38.4451 0 36.9862 0C34.5431 0 32.7385 1.92172 32.7385 4.69297C32.7385 7.4115 34.4259 9.42696 36.8339 9.42696C38.3455 9.42696 39.3356 8.78834 39.9391 8.12629L40.0387 8.67116C40.0973 9.0227 40.3317 9.21604 40.7008 9.21604H41.7319C42.1186 9.21604 42.353 8.98169 42.353 8.595V0.831963C42.3471 0.445276 42.1128 0.21092 41.7261 0.21092ZM37.5487 7.15957C36.1718 7.15957 35.2989 6.21043 35.2989 4.73399C35.2989 3.23997 36.2129 2.26739 37.5487 2.26739C38.9255 2.26739 39.7985 3.21653 39.7985 4.69297C39.8044 6.19285 38.8904 7.15957 37.5487 7.15957Z" fill="currentColor"></path><path d="M31.186 0.21092H30.1197C29.7506 0.21092 29.4987 0.404264 29.4401 0.773374L29.3815 1.21865C28.778 0. ...

# %% [markdown]
# Podemos verificar se a o texto de resposta possui algum termo com

# %%
'128GB' in resposta.text
# Out:
# True

# %% [markdown]
# Vamos criar um soup para conseguir extrair informações a partir do HTML

# %%
soup = BeautifulSoup(resposta.text, 'html.parser')

# %% [markdown]
# Qual a tag que identifica um produto? Vamos procurar o primeiro produto da lista

# %%
lista_prod = soup.find('div', attrs={'data-testid': 'mod-productlist'})
lista_prod
# Out:
# <div class="sc-eDvSVe koHJnT" data-testid="mod-productlist"><div class="sc-hLBbgP eZMgoD sc-fCBrnK ljivsi" data-testid="product-list"><ul class="sc-bCfvAP jdNdfB sc-cLNonn jyhgZO sc-jbwHOj ksfOdh" data-testid="list"><li class="sc-ibdxON fwviCj"><a class="sc-hhOBVt jZChDm sc-izDtrv bLwhHK sc-izDtrv bLwhHK" data-testid="product-card-container" href="/smartphone-samsung-galaxy-s23-128gb-violeta-5g-8gb-ram-61-cam-tripla-selfie-12mp/p/232853400/te/galx/"><div class="sc-febvLc eBkTGO"><p class="sc-kDvujY gfGDOa sc-ePBJll WYOAR" color="#404040" font-size="13" font-weight="regular">Patrocinado</p><button class="sc-dmctIk egNKll sc-hTRxPq jpnxkN sc-iOdfRm KigBa" data-testid="add-wishlist-button" role="button"><svg class="sc-dkrFOg egyRwi sc-cSyrqk eTRIFp" data-testid="empty-icon" fill="transparent" stroke="darkGray" viewbox="0 0 29 25"><g fill-rule="evenodd"><path d="M1.49172 11.6365C5.44539 16.9514 8.70455 19.3673 14.1409 24.199C19.7248 19.3076 22.984 16.8619 27.0451 11.4813C28.673 8.73748 27.163 4.74656 25.0145 2.67681C23.3588 1.08145 21.448 0.964921 19.4175 1.45406C16.7335 2.17623 15.8645 2.92149 14.3412 4.38891C12.8582 2.9394 12.0121 2.20322 9.39906 1.48986C7.42226 1.00669 5.08049 1.3635 3.46857 2.93939C1.37694 4.98389 -0.305622 9.22065 1.49172 11.6365Z" fill="currentColor" stroke-width="5%"></path></g></svg></button></div><div class="sc-eQVdPn clJokE"><img alt="Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP" class="sc-jIRcFI iilPOm" data-testid="image" height="" loading="lazy" offset="50" src="https://a-static.mlcdn.com.br/280x210/smartphone-samsung-galaxy-s23-128gb-violeta-5g-8gb-ram-61-cam-tripla-selfie-12mp/magazineluiza/232853400/8f3b8b9e361c5a764ee7cfd668404e75.jpg" title="Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP" width=""/><div class="sc-kOjCZu liUGwn"></div></div><div class="sc-cnOiCc kMzkrA" data-testid="product-card-content"><h2 class="sc-hFVsQR hQYVAI" data-testid="product-title" font-size="1,2,2" font-weight="regular">Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP</h2><div class="sc-hLBbgP gcxrmT sc-iuuDEZ hTFiVL"><div class="sc-hLBbgP blWoJz sc-gGfaQS dhvIhC" data-testid="price-default" font-size="3,5"><p class="sc-kDvujY gcLiKJ sc-ehkVkK jxmyPO" color="text.scratched" data-testid="price-original" font-size="0,1">R$ 5.999,00</p><p class="sc-kDvujY jDmBNY sc-hGglLj bQqJoc" color="#404040" data-testid="price-value">R$ 5.309,10</p><span data-testid="in-cash">no PIX<!-- --> </span><span class="sc-dcntqk kfbztu">(<!-- -->10% de desconto<!-- -->)</span><p class="sc-kDvujY szpaO sc-kSGOQU hefOAQ" color="#404040" data-testid="installment" font-size="0,1" font-weight="regular">ou <!-- -->10<!-- -->x de <!-- -->R$ 589,90<!-- --> <!-- -->sem juros</p></div></div><div class="sc-jrcTuL kMZcJF sc-UTuSi hYdUkp" data-testid="product-variations-container" height="18px"><p class="sc-kDvujY cOQarI sc-goETIM gPiajX" color="#bcbcbc" font-size="14" font-weight="medium">4<!-- --> <!-- -->cores</p></div></div></a></li><li class="sc-ibdxON fwviCj"><a class="sc-hhOBVt jZChDm sc-izDtrv bLwhHK sc-izDtrv bLwhHK" data-testid="product-card-container" href="/smartphone-samsung-galaxy-s23-128gb-preto-5g-8gb-ram-61-cam-tripla-selfie-12mp/p/232853700/te/galx/"><div class="sc-febvLc eBkTGO"><p class="sc-kDvujY gfGDOa sc-ePBJll WYOAR" color="#404040" font-size="13" font-weight="regular">Patrocinado</p><button class="sc-dmctIk egNKll sc-hTRxPq jpnxkN sc-iOdfRm KigBa" data-testid="add-wishlist-button" role="button"><svg class="sc-dkrFOg egyRwi sc-cSyrqk eTRIFp" data-testid="empty-icon" fill="transparent" stroke="darkGray" viewbox="0 0 29 25"><g fill-rule="evenodd"><path d="M1.49172 11.6365C5.44539 16.9514 8.70455 19.3673 14.1409 24.199C19.7248 19.3076 22.984 16.8619 27.0451 11.4813C28.673 8.73748 27.163 4.74656 25.0145 2.67681C23.3588 1.08145 21.448 0.964921 19.4175 1.45406C16.7335 2.17623 15.8645 2.92149 14.3412 4.38891C12.8582 2.9394 12. ...

# %%
tag_produto = lista_prod.find('li')
tag_produto
# Out:
# <li class="sc-ibdxON fwviCj"><a class="sc-hhOBVt jZChDm sc-izDtrv bLwhHK sc-izDtrv bLwhHK" data-testid="product-card-container" href="/smartphone-samsung-galaxy-s23-128gb-violeta-5g-8gb-ram-61-cam-tripla-selfie-12mp/p/232853400/te/galx/"><div class="sc-febvLc eBkTGO"><p class="sc-kDvujY gfGDOa sc-ePBJll WYOAR" color="#404040" font-size="13" font-weight="regular">Patrocinado</p><button class="sc-dmctIk egNKll sc-hTRxPq jpnxkN sc-iOdfRm KigBa" data-testid="add-wishlist-button" role="button"><svg class="sc-dkrFOg egyRwi sc-cSyrqk eTRIFp" data-testid="empty-icon" fill="transparent" stroke="darkGray" viewbox="0 0 29 25"><g fill-rule="evenodd"><path d="M1.49172 11.6365C5.44539 16.9514 8.70455 19.3673 14.1409 24.199C19.7248 19.3076 22.984 16.8619 27.0451 11.4813C28.673 8.73748 27.163 4.74656 25.0145 2.67681C23.3588 1.08145 21.448 0.964921 19.4175 1.45406C16.7335 2.17623 15.8645 2.92149 14.3412 4.38891C12.8582 2.9394 12.0121 2.20322 9.39906 1.48986C7.42226 1.00669 5.08049 1.3635 3.46857 2.93939C1.37694 4.98389 -0.305622 9.22065 1.49172 11.6365Z" fill="currentColor" stroke-width="5%"></path></g></svg></button></div><div class="sc-eQVdPn clJokE"><img alt="Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP" class="sc-jIRcFI iilPOm" data-testid="image" height="" loading="lazy" offset="50" src="https://a-static.mlcdn.com.br/280x210/smartphone-samsung-galaxy-s23-128gb-violeta-5g-8gb-ram-61-cam-tripla-selfie-12mp/magazineluiza/232853400/8f3b8b9e361c5a764ee7cfd668404e75.jpg" title="Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP" width=""/><div class="sc-kOjCZu liUGwn"></div></div><div class="sc-cnOiCc kMzkrA" data-testid="product-card-content"><h2 class="sc-hFVsQR hQYVAI" data-testid="product-title" font-size="1,2,2" font-weight="regular">Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP</h2><div class="sc-hLBbgP gcxrmT sc-iuuDEZ hTFiVL"><div class="sc-hLBbgP blWoJz sc-gGfaQS dhvIhC" data-testid="price-default" font-size="3,5"><p class="sc-kDvujY gcLiKJ sc-ehkVkK jxmyPO" color="text.scratched" data-testid="price-original" font-size="0,1">R$ 5.999,00</p><p class="sc-kDvujY jDmBNY sc-hGglLj bQqJoc" color="#404040" data-testid="price-value">R$ 5.309,10</p><span data-testid="in-cash">no PIX<!-- --> </span><span class="sc-dcntqk kfbztu">(<!-- -->10% de desconto<!-- -->)</span><p class="sc-kDvujY szpaO sc-kSGOQU hefOAQ" color="#404040" data-testid="installment" font-size="0,1" font-weight="regular">ou <!-- -->10<!-- -->x de <!-- -->R$ 589,90<!-- --> <!-- -->sem juros</p></div></div><div class="sc-jrcTuL kMZcJF sc-UTuSi hYdUkp" data-testid="product-variations-container" height="18px"><p class="sc-kDvujY cOQarI sc-goETIM gPiajX" color="#bcbcbc" font-size="14" font-weight="medium">4<!-- --> <!-- -->cores</p></div></div></a></li>

# %% [markdown]
# Como podemos extrair a Descrição?

# %%
desc_produto = tag_produto.find('h2', class_ = "sc-hFVsQR hQYVAI")
desc_produto.text
# Out:
# 'Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP'

# %% [markdown]
# E para extrair o Preço?

# %%
preco_produto = tag_produto.find('p', class_="sc-kDvujY jDmBNY sc-hGglLj bQqJoc")
print(preco_produto.text)
# Out:
# R$ 5.309,10

# %% [markdown]
# ### Procurando por todos os produtos
#
# Vamos extrair a lista de produtos (suas tags) e iterar sobre elas para extrair informações de vários produtos. Por enquanto, considere a extração das duas primeiras linhas de informação no site (oito produtos).

# %%
lista_prod = soup.find('div', attrs={'data-testid': 'mod-productlist'})
lista_tag_produto = lista_prod.find_all('li')

# %%
qt_prod = len(lista_tag_produto)
qt_prod
# Out:
# 54

# %%
lista_desc = []
lista_preco = []
for i in range(8):
    tag_produto = lista_tag_produto[i]

    desc_produto = tag_produto.find('h2', class_ = "sc-hFVsQR hQYVAI")
    lista_desc.append(desc_produto.text)

    preco_produto = tag_produto.find('p', class_="sc-kDvujY jDmBNY sc-hGglLj bQqJoc")

    if preco_produto == None:
        preco_produto = None
    else:    
        preco_clean = preco_produto.text.replace('\n', '')
        preco_clean = preco_clean.strip()
        preco_clean = preco_clean.replace('R$', '')
        preco_clean = preco_clean.replace(".", "").replace(",", ".")
        preco_clean = float(preco_clean)
    
    lista_preco.append(preco_clean)

    
lista_preco
# Out:
# [5309.1, 5309.1, 999.0, 999.0, 999.0, 989.1, 1143.12, 989.1]

# %%
tag_produto
# Out:
# <li class="sc-ibdxON fwviCj"><a class="sc-hhOBVt jZChDm sc-izDtrv bLwhHK sc-izDtrv bLwhHK" data-testid="product-card-container" href="/smartphone-samsung-galaxy-m13-128gb-cobre-4g-octa-core-4gb-ram-66-cam-tripla-selfie-8mp/p/235392500/te/galx/"><div class="sc-febvLc hspvzo"><button class="sc-dmctIk egNKll sc-hTRxPq jpnxkN sc-iOdfRm KigBa" data-testid="add-wishlist-button" role="button"><svg class="sc-dkrFOg egyRwi sc-cSyrqk eTRIFp" data-testid="empty-icon" fill="transparent" stroke="darkGray" viewbox="0 0 29 25"><g fill-rule="evenodd"><path d="M1.49172 11.6365C5.44539 16.9514 8.70455 19.3673 14.1409 24.199C19.7248 19.3076 22.984 16.8619 27.0451 11.4813C28.673 8.73748 27.163 4.74656 25.0145 2.67681C23.3588 1.08145 21.448 0.964921 19.4175 1.45406C16.7335 2.17623 15.8645 2.92149 14.3412 4.38891C12.8582 2.9394 12.0121 2.20322 9.39906 1.48986C7.42226 1.00669 5.08049 1.3635 3.46857 2.93939C1.37694 4.98389 -0.305622 9.22065 1.49172 11.6365Z" fill="currentColor" stroke-width="5%"></path></g></svg></button></div><div class="sc-eQVdPn clJokE"><img alt="Smartphone Samsung Galaxy M13 128GB Cobre 4G Octa-Core 4GB RAM 6,6” Câm. Tripla + Selfie 8MP" class="sc-jIRcFI iilPOm" data-testid="image" height="" loading="lazy" offset="50" src="https://a-static.mlcdn.com.br/280x210/smartphone-samsung-galaxy-m13-128gb-cobre-4g-octa-core-4gb-ram-66-cam-tripla-selfie-8mp/magazineluiza/235392500/a28f2dda32c089ee2eb8d990b9c4f3f8.jpg" title="Smartphone Samsung Galaxy M13 128GB Cobre 4G Octa-Core 4GB RAM 6,6” Câm. Tripla + Selfie 8MP" width=""/><div class="sc-kOjCZu liUGwn"></div></div><div class="sc-cnOiCc kMzkrA" data-testid="product-card-content"><h2 class="sc-hFVsQR hQYVAI" data-testid="product-title" font-size="1,2,2" font-weight="regular">Smartphone Samsung Galaxy M13 128GB Cobre 4G Octa-Core 4GB RAM 6,6” Câm. Tripla + Selfie 8MP</h2><div class="sc-bkldj lcdELo"><div class="sc-hgRfpC fOZTRE" data-testid="review"><span class="sc-fiSPbx dTLdPM" color="text.scratched" font-size="0,1,1" font-weight="regular" format="count">1035</span></div></div><div class="sc-hLBbgP gcxrmT sc-iuuDEZ hTFiVL"><div class="sc-hLBbgP blWoJz sc-gGfaQS dhvIhC" data-testid="price-default" font-size="3,5"><p class="sc-kDvujY gcLiKJ sc-ehkVkK jxmyPO" color="text.scratched" data-testid="price-original" font-size="0,1">R$ 1.699,00</p><p class="sc-kDvujY jDmBNY sc-hGglLj bQqJoc" color="#404040" data-testid="price-value">R$ 989,10</p><span data-testid="in-cash">no PIX<!-- --> </span><span class="sc-dcntqk kfbztu">(<!-- -->10% de desconto<!-- -->)</span><p class="sc-kDvujY szpaO sc-kSGOQU hefOAQ" color="#404040" data-testid="installment" font-size="0,1" font-weight="regular">ou <!-- -->9<!-- -->x de <!-- -->R$ 122,11<!-- --> <!-- -->sem juros</p></div></div><div class="sc-jrcTuL kMZcJF sc-UTuSi hYdUkp" data-testid="product-variations-container" height="18px"><p class="sc-kDvujY cOQarI sc-goETIM gPiajX" color="#bcbcbc" font-size="14" font-weight="medium">3<!-- --> <!-- -->cores</p></div></div></a></li>

# %%
lista_desc
# Out:
# ['Smartphone Samsung Galaxy S23 128GB Violeta 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP',
#  'Smartphone Samsung Galaxy S23 128GB Preto 5G 8GB RAM 6,1” Câm Tripla + Selfie 12MP',
#  'Smartphone Samsung Galaxy A13 128GB Branco 4G Octa-Core 4GB RAM 6,6” Câm Quádrupla + Selfie 8MP',
#  'Smartphone Samsung Galaxy A13 128GB Preto 4G Octa-Core 4GB RAM 6,6” Câm Quádrupla + Selfie 8MP',
#  'Smartphone Samsung Galaxy A13 128GB Azul 4G Octa-Core 4GB RAM 6,6” Câm Quádrupla + Selfie 8MP',
#  'Smartphone Samsung Galaxy M13 128GB Azul 4G Octa-Core 4GB RAM 6,6” Câm. Tripla + Selfie 8MP',
#  'Smartphone Motorola Moto G32 128GB Rosé 4G Octa-Core 4GB RAM 6,5” Câm. Tripla + Selfie 16MP',
#  'Smartphone Samsung Galaxy M13 128GB Cobre 4G Octa-Core 4GB RAM 6,6” Câm. Tripla + Selfie 8MP']

# %% [markdown]
# #### Criar DataFrame
#
# Então, podemos facilmente transformar as listas extraídas em um DataFrame do pandas

# %%
busca = 'smarpthone 64GB'
df = pd.DataFrame({'Busca': busca,
                   'Descrição': lista_desc,
                   'Preço': lista_preco
                  })
df
# Out:
#              Busca                                          Descrição    Preço
# 0  smarpthone 64GB  Smartphone Samsung Galaxy S23 128GB Violeta 5G...  5309.10
# 1  smarpthone 64GB  Smartphone Samsung Galaxy S23 128GB Preto 5G 8...  5309.10
# 2  smarpthone 64GB  Smartphone Samsung Galaxy A13 128GB Branco 4G ...   999.00
# 3  smarpthone 64GB  Smartphone Samsung Galaxy A13 128GB Preto 4G O...   999.00
# 4  smarpthone 64GB  Smartphone Samsung Galaxy A13 128GB Azul 4G Oc...   999.00
# 5  smarpthone 64GB  Smartphone Samsung Galaxy M13 128GB Azul 4G Oc...   989.10
# 6  smarpthone 64GB  Smartphone Motorola Moto G32 128GB Rosé 4G Oct...  1143.12
# 7  smarpthone 64GB  Smartphone Samsung Galaxy M13 128GB Cobre 4G O...   989.10

# %% [markdown]
# ## Criando funções
#
# Vamos criar funções para fazer uma busca, tratar os dados obter um DataFrame.
#
# Função que pesquisa por um termo no site e retorna o HTML como um texto

# %%
def pesquisa(termo):
    
    s1 = random.randint(1,40)
    s2 = random.randint(1,140)
    
    headers = {
         'user-agent': f'Mozilla/5.0  (Windows NT 10.0; Win64; x64) AppleWebKit/537.{s1} (KHTML, like Gecko) Chrome/75.0.3770.{s2} Safari/537.{s1}'
    }
    
    url = f'https://www.magazineluiza.com.br/busca/smartphone+{termo}/'
    
    time.sleep(abs(random.gauss(2,1)))

    resposta = requests.get(url = url, headers=headers)

    resposta.encoding = 'utf-8'

    return resposta.text

# %% [markdown]
# Função que processa o HTML e extrai a descrição, preço e demais informações necessárias

# %%
def processa(resposta, qtde_produto):
    
    soup = BeautifulSoup(resposta, 'html.parser')
    
    lista_prod = soup.find('div', attrs={'data-testid': 'mod-productlist'})
    lista_tag_produto = lista_prod.find_all('li')
    
    lista_desc = []
    lista_preco = []
    lista_ranking = []
    
    for i in range(qtde_produto):
        tag_produto = lista_tag_produto[i]
        desc_produto = tag_produto.find('h2', class_ = "sc-hFVsQR hQYVAI")
        lista_desc.append(desc_produto.text)

        preco_produto = tag_produto.find('p', class_="sc-kDvujY jDmBNY sc-hGglLj bQqJoc")

        if preco_produto == None:
            preco_produto = None
        else:    
            preco_clean = preco_produto.text.replace('\n', '')
            preco_clean = preco_clean.strip()
            preco_clean = preco_clean.replace('R$', '')
            preco_clean = preco_clean.replace(".", "").replace(",", ".")
            preco_clean = float(preco_clean)

        lista_preco.append(preco_clean)
        
        lista_ranking.append(i+1)
        
    return lista_desc, lista_preco, lista_ranking

# %% [markdown]
# Função que gera um DataFrame a partir de listas de informações dos produtos

# %%
def gera_df(termo, lista_desc, lista_preco, lista_ranking):
    df = pd.DataFrame({'Pesquisa': termo,
                       'Ranking': lista_ranking,
                       'Descrição': lista_desc,
                       'Preço': lista_preco
                      })
    return df

# %% [markdown]
# Função para chamar as demais funções e retornar um DataFrame

# %%
def pesquisa_estruturada(termo, qtde_produto):
    texto = pesquisa(termo)
    lista_desc, lista_preco, lista_ranking = processa(texto, qtde_produto)
    return gera_df(termo, lista_desc, lista_preco, lista_ranking)

# %%
df = pesquisa_estruturada('64gb', 8)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-e931ed2982f7> in <module>
# ----> 1 df = pesquisa_estruturada('64gb', 8)
#       2 df
#
# <ipython-input-86-ed127a420775> in pesquisa_estruturada(termo, qtde_produto)
#       1 def pesquisa_estruturada(termo, qtde_produto):
#       2     texto = pesquisa(termo)
# ----> 3     lista_desc, lista_preco, lista_ranking = processa(texto, qtde_produto)
#       4     return gera_df(termo, lista_desc, lista_preco, lista_ranking)
#
# <ipython-input-84-1205c0a5034b> in processa(resposta, qtde_produto)
#       4
#       5     lista_prod = soup.find('div', attrs={'data-testid': 'mod-productlist'})
# ----> 6     lista_tag_produto = lista_prod.find_all('li')
#       7
#       8     lista_desc = []
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# Como concatenar DataFrames para juntar o resultado de diversas buscas?

# %%
pd.concat([pesquisa_estruturada('64gb', 4), pesquisa_estruturada('128gb', 4)])

# %% [markdown]
# Então, podemos criar uma função que recebe uma lista de termos de busca, efetua a pesquisa de cada termo e junta os DataFrames ao final!

# %%
def multi_pesquisa(lista_busca, qtde_produto):
    time.sleep(random.randint(3,6))
    lista_df = []
    for termo in lista_busca:
        df = pesquisa_estruturada(termo, qtde_produto)
        lista_df.append(df)
        time.sleep(0.5)
    df_full = pd.concat(lista_df)
    return df_full.reset_index(drop=True)

# %%
# Termos a serem pesquisados
lista_busca = ['32Gb', '64Gb', '128Gb', '256Gb']

df = multi_pesquisa(lista_busca, 50)
df.head()

# %%
df.tail()

# %%
df

# %% [markdown]
# # Exercícios
#
# Utilizando os dados obtidos no Magalu:
#
# **Exercício 4)** Calcule o preço médio produtos:
#
# a) Geral

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# b) Por termo de busca
#
# Dica: groupby

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# a) Os preços médios obtidos fazem sentido?

# %% [markdown]
# R:

# %% [markdown]
# b) Produza um gráfico de barras com os preços médios

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 5)** Crie uma coluna que informe se o produto é de cor discreta ou não.
#
# Dica: pesquise pelos termos *black*, *preto*, *gray*, *branco*, etc.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# a) Compare o preço médio dos produtos que são e não são de cor discreta.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 6)** Conte quantos produtos são das marcas **Samsung**, **Motorola** e **LG**.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 7)** Crie uma coluna de Marca no DataFrame, informando se é **Samsung**, **Motorola**, **LG** ou **Outra**.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 8)** Altere o código que processa os dados de resposta para retornar também (até o DataFrame) uma coluna de **ranking**, informando se o produto aparece na primeira, segunda, n-ésima posição da busca.
#
# a) Calcule o preço médio dos produtos das primeiras quatro posições de busca.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# b) Calcule a probabilidade de cada Marca aparecer em cada uma das quatro primeiras posições de busca.
#
# Dica: você precisa de uma tabela cruzada normalizada

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# c) Exiba a informação anterior em um mapa de calor.
#
# Dica: utilize a função **heatmap** da biblioteca **seaborn**, ou a função **imshow** da biblioteca **plotly.express**.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# d) Calcule o preço médio cruzando ranking e marca.
#
# Dica: você precisa de uma pivot_table

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# **Exercício 9)** Escolha um site de seu interesse e tente fazer o Web scraping dos seus dados. Gere e exporte para CSV um `DataFrame` contendo informações de interesse do site.

# %%
#SEU CODIGO AQUI!

# %% [markdown]
# ## Combinando termos de busca
#
# Uma outra abordagem de busca poderia ser pesquisar utilizando diversas características.
#
# Tendo os termos separados em listas, existe uma forma de combinar todos eles de forma fácil (produto cartesiano)

# %%
# !pip install sklearn

# %%
lista_marca = ['Samsung', 'Motorola', 'LG', 'Xiaomi', 'Apple']
lista_mem = ['64Gb', '128Gb', '256Gb']
lista_cor = ['Gold', 'Preto', 'Azul']

df_busca = pd.DataFrame(cartesian((lista_marca, lista_mem, lista_cor)), columns=['Marca', 'Memória', 'Cor'])
df_busca

# %% [markdown]
# Seria necessário alterar o código de pesquisa para concatenar os termos de busca e retorná-los também no DataFrame. Não precisa fazer! Esta é apenas uma sugestão.
